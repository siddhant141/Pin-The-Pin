# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import concurrent.futures

# %%
folder="Gyro"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\"+folder+"\\"
pathex=[]
temp = [f for f in listdir(path) if isfile(join(path, f))]
# temp.sort()
# files=["4b0c10"]
files=["4b0c09"]
# files=["a29c08","66b325","b56522"]
# files=["a29c12","a29c08","66b325","b56522"]
# files=["66b325","b56522"]
for i in range(len(temp)):
    st=temp[i]
    if(os.path.getsize(path+st)<4096):
        continue
    if(temp[i][:6] in files):
        pathex.append(temp[i])
#     if(files[0]=="all"):
#         pathex.append(temp[i])
# print(pathex)
print(len(temp))
print(len(pathex))
# Out:
# 2445
# 80

# %%
# folder_n_no.ofvalues_no.offiles_keycolno.
propath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Processed\\"
def savefile():
    df.to_csv (propath+folder+"_"+str(n)+"_"+fcode+"_"+"&".join(files)+"_"+str(keypos)+".csv", index = False, header=True)

# %%
#taking into account that error might occur while reading a file (putting try and except)
# n -> number of lines in csv file
# actual -> the actual key pressed
# minkeyd -> index of nearest key down time
# minkeyu -> index of nearest key up time
# keydt -> key down time from file name
# keyut -> key up time from file name
fcode="wininituni"
n=400
keypos=1
actual=1
df=pd.read_csv(path + pathex[0])
for i in range(len(pathex)):
    try:
        #removing initial values
#         print(pathex[i])
        dff=pd.read_csv(path+pathex[i])
        for j in dff.index:
            if(dff["Time"][j]>10):
                break
        winerr=dff["Time"][j]
        dff=dff.tail(dff.size-j)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")
        
#         dfuni = pd.DataFrame(columns = ["Time","X","Y","Z"])
# dff["Time"].iloc[-1]
        dfuni = pd.DataFrame(0.0, index=np.arange(dff["Time"].iloc[-1]+2), columns=["X","Y","Z"])
        k=0
        sumx=0
        sumy=0
        sumz=0
        for j in dfuni.index:
            while(k<dff.index[-1] and dff["Time"][k]==dff["Time"][k+1]):
                k+=1
            if(k>dff.index[-1]):
                break
#             print("j : ",j)
#             print("dff Time : ",dff["Time"][k])
#             print("dff : ",dff["Time"][k]-dff["Time"][0])
            if(j==dff["Time"][k]-dff["Time"][0]):
#                 print("match")
                dfuni["X"][j]=dff["X"][k]
                dfuni["Y"][j]=dff["Y"][k]
                dfuni["Z"][j]=dff["Z"][k]
                k+=1
            else:
#                 print("no match")
                dfuni["X"][j]=dfuni["X"][j-1]
                dfuni["Y"][j]=dfuni["Y"][j-1]
                dfuni["Z"][j]=dfuni["Z"][j-1]
            if(j<300):
                sumx+=dff["X"][j]
                sumy+=dff["Y"][j]
                sumz+=dff["Z"][j]
#         print(dff["Time"][k-1])
        dfuni=dfuni.head(j)
#         print(dfuni)
        
        keydt=pathex[i].rfind("_")+4
        minkeyd=int(pathex[i][keydt:-4])+winerr
        
        dff=dfuni
        avg=[sumx/300,sumy/300,sumz/300]
        
        for j in dff.index:
            dff['X'][j]=abs(dff['X'][j]-avg[0])
            dff['Y'][j]=abs(dff['Y'][j]-avg[1])
            dff['Z'][j]=abs(dff['Z'][j]-avg[2])
#         print(dff)
        
#         window=minkeyu-minkeyd
        left=int(n/2)-1
        dff=dff.head(minkeyd + left)
        dff=dff.tail(n)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")
        df1=dff.stack().swaplevel()        
        df1.index=df1.index.map('{0[0]}_{0[1]}'.format) 
        dff=df1.to_frame().T
        ind=pathex[i].rfind("_")+3
        print(i,pathex[i])
        dff.insert(n*3, "key", int(pathex[i][ind]))
        keypos=n*3
        if(i==0):
            df=dff
        else:
            df=df.append(dff,ignore_index = True)
    except:
        print("error : ",pathex[i])
#         traceback.print_exec()
        continue
# Out:
# 0 4b0c09-04-2020_104956_PM81244.csv
# 1 4b0c09-04-2020_104958_PM2759.csv
# 2 4b0c09-04-2020_105000_PM5658.csv
# 3 4b0c09-04-2020_105002_PM6600.csv
# 4 4b0c09-04-2020_105004_PM4688.csv
# 5 4b0c09-04-2020_105006_PM5731.csv
# 6 4b0c09-04-2020_105008_PM3591.csv
# 7 4b0c09-04-2020_105009_PM4680.csv
# 8 4b0c09-04-2020_105011_PM5578.csv
# 9 4b0c09-04-2020_105013_PM3611.csv
# 10 4b0c09-04-2020_105015_PM7734.csv
# 11 4b0c09-04-2020_105017_PM1801.csv
# 12 4b0c09-04-2020_105018_PM5637.csv
# 13 4b0c09-04-2020_105020_PM0699.csv
# 14 4b0c09-04-2020_105022_PM1662.csv
# 15 4b0c09-04-2020_105024_PM8685.csv
# 16 4b0c09-04-2020_105026_PM7646.csv
# 17 4b0c09-04-2020_105028_PM6686.csv
# 18 4b0c09-04-2020_105029_PM1665.csv
# 19 4b0c09-04-2020_105031_PM0609.csv
# 20 4b0c09-04-2020_105033_PM9695.csv
# 21 4b0c09-04-2020_105035_PM8675.csv
# 22 4b0c09-04-2020_105037_PM6627.csv
# 23 4b0c09-04-2020_105039_PM9776.csv
# 24 4b0c09-04-2020_105040_PM8679.csv
# 25 4b0c09-04-2020_105042_PM2621.csv
# 26 4b0c09-04-2020_105044_PM6661.csv
# 27 4b0c09-04-2020_105046_PM1678.csv
# 28 4b0c09-04-2020_105048_PM2673.csv
# 29 4b0c09-04-2020_105050_PM2813.csv
# 30 4b0c09-04-2020_105051_PM3652.csv
# 31 4b0c09-04-2020_105053_PM3939.csv
# 32 4b0c09-04-2020_105055_PM9710.csv
# 33 4b0c09-04-2020_105057_PM4644.csv
# 34 4b0c09-04-2020_105059_PM7798.csv
# 35 4b0c09-04-2020_105101_PM7873.csv
# 36 4b0c09-04-2020_105103_PM9765.csv
# 37 4b0c09-04-2020_105104_PM0715.csv
# 38 4b0c09-04-2020_105106_PM4673.csv
# 39 4b0c09-04-2020_105108_PM0646.csv
# 40 4b0c09-04-2020_111329_PM1763.csv
# 41 4b0c09-04-2020_111331_PM2747.csv
# 42 4b0c09-04-2020_111333_PM2675.csv
# 43 4b0c09-04-2020_111335_PM3580.csv
# 44 4b0c09-04-2020_111336_PM9884.csv
# 45 4b0c09-04-2020_111338_PM0747.csv
# 46 4b0c09-04-2020_111340_PM7658.csv
# 47 4b0c09-04-2020_111342_PM7789.csv
# 48 4b0c09-04-2020_111344_PM7737.csv
# 49 4b0c09-04-2020_111346_PM0679.csv
# 50 4b0c09-04-2020_111348_PM2654.csv
# 51 4b0c09-04-2020_111349_PM9596.csv
# 52 4b0c09-04-2020_111351_PM4748.csv
# 53 4b0c09-04-2020_111353_PM8539.csv
# 54 4b0c09-04-2020_111355_PM9616.csv
# 55 4b0c09-04-2020_111357_PM1632.csv
# 56 4b0c09-04-2020_111358_PM7764.csv
# 57 4b0c09-04-2020_111400_PM6610.csv
# 58 4b0c09-04-2020_111402_PM0667.csv
# 59 4b0c09-04-2020_111404_PM8760.csv
# 60 4b0c09-04-2020_111406_PM5726.csv
# 61 4b0c09-04-2020_111407_PM4728.csv
# 62 4b0c09-04-2020_111409_PM6854.csv
# 63 4b0c09-04-2020_111411_PM8655.csv
# 64 4b0c09-04-2020_111413_PM3733.csv
# 65 4b0c09-04-2020_111415_PM6732.csv
# 66 4b0c09-04-2020_111417_PM5773.csv
# 67 4b0c09-04-2020_111419_PM8773.csv
# 68 4b0c09-04-2020_111420_PM9792.csv
# 69 4b0c09-04-2020_111422_PM0691.csv
# 70 4b0c09-04-2020_111424_PM6651.csv
# 71 4b0c09-04-2020_111426_PM1773.csv
# 72 4b0c09-04-2020_111428_PM1809.csv
# 73 4b0c09-04-2020_111430_PM5787.csv
# 74 4b0c09-04-2020_111431_PM2771.csv
# 75 4b0c09-04-2020_111433_PM3644.csv
# 76 4b0c09-04-2020_111435_PM3741.csv
# 77 4b0c09-04-2020_111437_PM4661.csv
# 78 4b0c09-04-2020_111439_PM4702.csv
# 79 4b0c09-04-2020_111440_PM5610.csv

# %%
savefile()
