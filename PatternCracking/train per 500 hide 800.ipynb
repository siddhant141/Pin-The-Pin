# %%
import pandas as pd
import numpy as np
import os
from math import ceil
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score
import pickle

# %%
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    iters=500
#     file=pathex[0]
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    dfuni=pd.read_csv(path+file)
    last=ceil(dfuni.index[-1]/iters)
    print(dfuni.index[-1])
    print(last)

#     fpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Results\\"
#     f = open(fpath+file+"idenhide"+".txt", "w")
#     f.write("\n"+str(dfuni.index[-1]))
#     f.write("\n"+str(last))

#     fl = open(fpath+file+"loghide"+".txt", "w")
#     fl.write("\n"+str(dfuni.index[-1]))
#     fl.write("\n"+str(last))

    X = dfuni.iloc[:, 0:n].values
    y = dfuni.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.075)

    logmodel=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity",hidden_layer_sizes=(800,10))
#     logmodell=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic",hidden_layer_sizes=(800,10))

    for i in range(last):

        if(i!=last-1):
            X = X_train[:iters*(i+1)]
            y = y_train[:iters*(i+1)]
        else:
            X=X_train
            y=y_train

        print(X_train.size,X.size)
#         f.write("\n"+str(X_train.size)+str(X.size))
#         fl.write("\n"+str(X_train.size)+str(X.size))

        logmodel.fit(X, y)
#         logmodell.fit(X, y)
        y_pred = logmodel.predict(X_test)
#         y_predl = logmodell.predict(X_test)

        p = logmodel.predict_proba(X_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        #     for i in range(len(y_test)):
        #         print(y_test[i],top_n[i])
        count=0
        count1=0
        count2=0
        count3=0
        count12=0
        for i in range(len(y_pred)):
            if(y_test[i] in top_n[i]):
                count+=1
            if(y_test[i] in top_n[i][:2]):
                count12+=1
            if(y_test[i] == top_n[i][0]):
                count1+=1
            elif(y_test[i] == top_n[i][1]):
                count2+=1
            elif(y_test[i] == top_n[i][2]):
                count3+=1
        #         print(y_test[i],y_pred[i])
        l=len(y_pred)
        print(file)
        print(l,count)
        print("Any one : ",count/l)
        print("At position 1 and 2 : ",count12/l)
        print("At position 1 : ",count1/l)
        print("At position 2 : ",count2/l)
        print("At position 3 : ",count3/l)
        print(accuracy_score(y_test, y_pred))

#         f.write("\n"+file)
#         f.write("\n"+str(l)+str(count))
#         f.write("\nAny one : "+str(count/l))
#         f.write("\nAt position 1 and 2 : "+str(count12/l))
#         f.write("\nAt position 1 : "+str(count1/l))
#         f.write("\nAt position 2 : "+str(count2/l))
#         f.write("\nAt position 3 : "+str(count3/l))
#         f.write("\n"+str(accuracy_score(y_test, y_pred)))
        
#         p = logmodell.predict_proba(X_test)
#         nn = 3
#         top_n = np.argsort(p)[:,:-nn-1:-1]
#         #     for i in range(len(y_test)):
#         #         print(y_test[i],top_n[i])
#         count=0
#         count1=0
#         count2=0
#         count3=0
#         count12=0
#         for i in range(len(y_predl)):
#             if(y_test[i] in top_n[i]):
#                 count+=1
#             if(y_test[i] in top_n[i][:2]):
#                 count12+=1
#             if(y_test[i] == top_n[i][0]):
#                 count1+=1
#             elif(y_test[i] == top_n[i][1]):
#                 count2+=1
#             elif(y_test[i] == top_n[i][2]):
#                 count3+=1
#         #         print(y_test[i],y_pred[i])
#         l=len(y_predl)
#         print(file)
#         print(l,count)
#         print("Any one : ",count/l)
#         print("At position 1 and 2 : ",count12/l)
#         print("At position 1 : ",count1/l)
#         print("At position 2 : ",count2/l)
#         print("At position 3 : ",count3/l)
#         print(accuracy_score(y_test, y_predl))

#         fl.write("\n"+file)
#         fl.write("\n"+str(l)+str(count))
#         fl.write("\nAny one : "+str(count/l))
#         fl.write("\nAt position 1 and 2 : "+str(count12/l))
#         fl.write("\nAt position 1 : "+str(count1/l))
#         fl.write("\nAt position 2 : "+str(count2/l))
#         fl.write("\nAt position 3 : "+str(count3/l))
#         fl.write("\n"+str(accuracy_score(y_test, y_predl)))

# #     f.close()
#     fl.close()
    
# filename = "zmlp500_"+file[:-4]+".sav"
# pickle.dump(logmodel, open(modelpath+filename, 'wb'))
# Out:
# 2711
# 6
# 6019200 1200000
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 180
# Any one :  0.8823529411764706
# At position 1 and 2 :  0.7647058823529411
# At position 1 :  0.5245098039215687
# At position 2 :  0.24019607843137256
# At position 3 :  0.11764705882352941
# 0.5245098039215687
# 6019200 2400000
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 180
# Any one :  0.8823529411764706
# At position 1 and 2 :  0.8284313725490197
# At position 1 :  0.5735294117647058
# At position 2 :  0.2549019607843137
# At position 3 :  0.05392156862745098
# 0.5735294117647058
# 6019200 3600000
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 182
# Any one :  0.8921568627450981
# At position 1 and 2 :  0.8431372549019608
# At position 1 :  0.6421568627450981
# At position 2 :  0.20098039215686275
# At position 3 :  0.049019607843137254
# 0.6421568627450981
# 6019200 4800000
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 185
# Any one :  0.9068627450980392
# At position 1 and 2 :  0.8235294117647058
# At position 1 :  0.6372549019607843
# At position 2 :  0.18627450980392157
# At position 3 :  0.08333333333333333
# 0.6372549019607843
# 6019200 6000000
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 186
# Any one :  0.9117647058823529
# At position 1 and 2 :  0.8627450980392157
# At position 1 :  0.6568627450980392
# At position 2 :  0.20588235294117646
# At position 3 :  0.049019607843137254
# 0.6568627450980392
# 6019200 6019200
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 204 186
# Any one :  0.9117647058823529
# At position 1 and 2 :  0.8676470588235294
# At position 1 :  0.6568627450980392
# At position 2 :  0.2107843137254902
# At position 3 :  0.04411764705882353
# 0.6568627450980392
