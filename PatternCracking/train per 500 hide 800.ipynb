# %%
import pandas as pd
import numpy as np
import os
from math import ceil
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score
import pickle

# %%
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\800\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    iters=500
#     file=pathex[0]
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    dfuni=pd.read_csv(path+file)
    last=ceil(dfuni.index[-1]/iters)
    print(dfuni.index[-1])
    print(last)

    fpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Results\\"
#     f = open(fpath+file+"idenhide"+".txt", "w")
#     f.write("\n"+str(dfuni.index[-1]))
#     f.write("\n"+str(last))

    fl = open(fpath+file+"loghide"+".txt", "w")
    fl.write("\n"+str(dfuni.index[-1]))
    fl.write("\n"+str(last))

    X = dfuni.iloc[:, 0:n].values
    y = dfuni.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.075)

#     logmodel=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity",hidden_layer_sizes=(800,10))
    logmodell=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic",hidden_layer_sizes=(800,10))

    for i in range(last):

        if(i!=last-1):
            X = X_train[:iters*(i+1)]
            y = y_train[:iters*(i+1)]
        else:
            X=X_train
            y=y_train

        print(X_train.size,X.size)
#         f.write("\n"+str(X_train.size)+str(X.size))
        fl.write("\n"+str(X_train.size)+str(X.size))

#         logmodel.fit(X, y)
        logmodell.fit(X, y)
#         y_pred = logmodel.predict(X_test)
        y_predl = logmodell.predict(X_test)

#         p = logmodel.predict_proba(X_test)
#         nn = 3
#         top_n = np.argsort(p)[:,:-nn-1:-1]
#         #     for i in range(len(y_test)):
#         #         print(y_test[i],top_n[i])
#         count=0
#         count1=0
#         count2=0
#         count3=0
#         count12=0
#         for i in range(len(y_pred)):
#             if(y_test[i] in top_n[i]):
#                 count+=1
#             if(y_test[i] in top_n[i][:2]):
#                 count12+=1
#             if(y_test[i] == top_n[i][0]):
#                 count1+=1
#             elif(y_test[i] == top_n[i][1]):
#                 count2+=1
#             elif(y_test[i] == top_n[i][2]):
#                 count3+=1
#         #         print(y_test[i],y_pred[i])
#         l=len(y_pred)
#         print(file)
#         print(l,count)
#         print("Any one : ",count/l)
#         print("At position 1 and 2 : ",count12/l)
#         print("At position 1 : ",count1/l)
#         print("At position 2 : ",count2/l)
#         print("At position 3 : ",count3/l)
#         print(accuracy_score(y_test, y_pred))

#         f.write("\n"+file)
#         f.write("\n"+str(l)+str(count))
#         f.write("\nAny one : "+str(count/l))
#         f.write("\nAt position 1 and 2 : "+str(count12/l))
#         f.write("\nAt position 1 : "+str(count1/l))
#         f.write("\nAt position 2 : "+str(count2/l))
#         f.write("\nAt position 3 : "+str(count3/l))
#         f.write("\n"+str(accuracy_score(y_test, y_pred)))
        
        p = logmodell.predict_proba(X_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        #     for i in range(len(y_test)):
        #         print(y_test[i],top_n[i])
        count=0
        count1=0
        count2=0
        count3=0
        count12=0
        for i in range(len(y_predl)):
            if(y_test[i] in top_n[i]):
                count+=1
            if(y_test[i] in top_n[i][:2]):
                count12+=1
            if(y_test[i] == top_n[i][0]):
                count1+=1
            elif(y_test[i] == top_n[i][1]):
                count2+=1
            elif(y_test[i] == top_n[i][2]):
                count3+=1
        #         print(y_test[i],y_pred[i])
        l=len(y_predl)
        print(file)
        print(l,count)
        print("Any one : ",count/l)
        print("At position 1 and 2 : ",count12/l)
        print("At position 1 : ",count1/l)
        print("At position 2 : ",count2/l)
        print("At position 3 : ",count3/l)
        print(accuracy_score(y_test, y_predl))

        fl.write("\n"+file)
        fl.write("\n"+str(l)+str(count))
        fl.write("\nAny one : "+str(count/l))
        fl.write("\nAt position 1 and 2 : "+str(count12/l))
        fl.write("\nAt position 1 : "+str(count1/l))
        fl.write("\nAt position 2 : "+str(count2/l))
        fl.write("\nAt position 3 : "+str(count3/l))
        fl.write("\n"+str(accuracy_score(y_test, y_predl)))

#     f.close()
    fl.close()
    
# filename = "zmlp500_"+file[:-4]+".sav"
# pickle.dump(logmodel, open(modelpath+filename, 'wb'))
# Out:
# 2357
# 5
# 5234400 1200000
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# 177 110
# Any one :  0.6214689265536724
# At position 1 and 2 :  0.4406779661016949
# At position 1 :  0.3163841807909605
# At position 2 :  0.12429378531073447
# At position 3 :  0.1807909604519774
# 0.3163841807909605
# 5234400 2400000
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# 177 112
# Any one :  0.632768361581921
# At position 1 and 2 :  0.5423728813559322
# At position 1 :  0.2994350282485876
# At position 2 :  0.24293785310734464
# At position 3 :  0.0903954802259887
# 0.2994350282485876
# 5234400 3600000
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# 177 124
# Any one :  0.7005649717514124
# At position 1 and 2 :  0.5819209039548022
# At position 1 :  0.3502824858757062
# At position 2 :  0.23163841807909605
# At position 3 :  0.11864406779661017
# 0.3502824858757062
# 5234400 4800000
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# 177 132
# Any one :  0.7457627118644068
# At position 1 and 2 :  0.5649717514124294
# At position 1 :  0.3559322033898305
# At position 2 :  0.20903954802259886
# At position 3 :  0.1807909604519774
# 0.3559322033898305
# 5234400 5234400
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# 177 151
# Any one :  0.8531073446327684
# At position 1 and 2 :  0.7570621468926554
# At position 1 :  0.559322033898305
# At position 2 :  0.1977401129943503
# At position 3 :  0.096045197740113
# 0.559322033898305
# 2616
# 6
# 5808000 1200000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 114
# Any one :  0.5786802030456852
# At position 1 and 2 :  0.4873096446700508
# At position 1 :  0.2893401015228426
# At position 2 :  0.19796954314720813
# At position 3 :  0.09137055837563451
# 0.2893401015228426
# 5808000 2400000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 126
# Any one :  0.6395939086294417
# At position 1 and 2 :  0.5279187817258884
# At position 1 :  0.3197969543147208
# At position 2 :  0.20812182741116753
# At position 3 :  0.1116751269035533
# 0.3197969543147208
# 5808000 3600000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 127
# Any one :  0.6446700507614214
# At position 1 and 2 :  0.5228426395939086
# At position 1 :  0.3248730964467005
# At position 2 :  0.19796954314720813
# At position 3 :  0.1218274111675127
# 0.3248730964467005
# 5808000 4800000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 129
# Any one :  0.6548223350253807
# At position 1 and 2 :  0.5380710659898477
# At position 1 :  0.3299492385786802
# At position 2 :  0.20812182741116753
# At position 3 :  0.116751269035533
# 0.3299492385786802
# 5808000 5808000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 138
# Any one :  0.700507614213198
# At position 1 and 2 :  0.5786802030456852
# At position 1 :  0.38578680203045684
# At position 2 :  0.19289340101522842
# At position 3 :  0.1218274111675127
# 0.38578680203045684
# 5808000 5808000
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# 197 134
# Any one :  0.6802030456852792
# At position 1 and 2 :  0.5786802030456852
# At position 1 :  0.36548223350253806
# At position 2 :  0.2131979695431472
# At position 3 :  0.10152284263959391
# 0.36548223350253806
# 2711
# 6
# 6019200 1200000
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 132
# Any one :  0.6470588235294118
# At position 1 and 2 :  0.47549019607843135
# At position 1 :  0.30392156862745096
# At position 2 :  0.1715686274509804
# At position 3 :  0.1715686274509804
# 0.30392156862745096
# 6019200 2400000
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 135
# Any one :  0.6617647058823529
# At position 1 and 2 :  0.553921568627451
# At position 1 :  0.35294117647058826
# At position 2 :  0.20098039215686275
# At position 3 :  0.10784313725490197
# 0.35294117647058826
# 6019200 3600000
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 140
# Any one :  0.6862745098039216
# At position 1 and 2 :  0.5833333333333334
# At position 1 :  0.4166666666666667
# At position 2 :  0.16666666666666666
# At position 3 :  0.10294117647058823
# 0.4166666666666667
# 6019200 4800000
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 149
# Any one :  0.7303921568627451
# At position 1 and 2 :  0.6323529411764706
# At position 1 :  0.47549019607843135
# At position 2 :  0.1568627450980392
# At position 3 :  0.09803921568627451
# 0.47549019607843135
# 6019200 6000000
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 157
# Any one :  0.7696078431372549
# At position 1 and 2 :  0.6176470588235294
# At position 1 :  0.45098039215686275
# At position 2 :  0.16666666666666666
# At position 3 :  0.15196078431372548
# 0.45098039215686275
# 6019200 6019200
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# 204 161
# Any one :  0.7892156862745098
# At position 1 and 2 :  0.6617647058823529
# At position 1 :  0.4950980392156863
# At position 2 :  0.16666666666666666
# At position 3 :  0.12745098039215685
# 0.4950980392156863
