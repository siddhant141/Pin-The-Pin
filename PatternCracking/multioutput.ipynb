# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Standardized\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]

# %%
def setmultioutput(x):
    if(x==1):
        return [1,2,4]
    if(x==2):
        return [1,2,5]
    if(x==3):
        return [3,5,6]
    if(x==4):
        return [5,7,8]
    if(x==5):
        return [6,8,9]
    if(x==6):
        return [3,5,9]
    if(x==7):
        return [4,5,8]
    if(x==8):
        return [5,9,0]
    if(x==9):
        return [6,8,9]
    if(x==0):
        return [8,9,0]

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    x = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
    temp1=[]
    temp11=[]
    temp111=[]
    for i in range(len(y_train)):
        t=setmultioutput(y_train[i])
        temp1.append(t[0])
        temp11.append(t[1])
        temp111.append(t[2])
    temp2=[]
    temp22=[]
    temp222=[]
    for i in range(len(y_test)):
        t=setmultioutput(y_test[i])
        temp2.append(t[0])
        temp22.append(t[1])
        temp222.append(t[2])
    y_train=np.vstack((y_train, temp1, temp11,temp111)).T
    y_test=np.vstack((y_test, temp2, temp22,temp222)).T
    model = RandomForestClassifier(n_estimators=10, random_state=0, max_depth=10)
#     model = KNeighborsClassifier(n_neighbors=7)
#     model = DecisionTreeClassifier(max_depth = 15)  
    logmodel = MultiOutputClassifier(model, n_jobs=-1)
    logmodel.fit(X_train, y_train)
    y_pred = logmodel.predict(X_train)
    print(file,end=" : ")
#     print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    count=0
    count1=0
    count2=0
    count3=0
    count4=0
    for i in range(len(y_pred)):
        if(y_test[i][0] in y_pred[i]):
            count+=1
        if(y_test[i][0] == y_pred[i][0]):
            count1+=1
        elif(y_test[i][0] == y_pred[i][1]):
            count2+=1
        elif(y_test[i][0] == y_pred[i][2]):
            count3+=1
        elif(y_test[i][0] == y_pred[i][3]):
            count4+=1
#         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(l,count)
    print(count/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
    print("At position 4 : ",count4/l)
#     df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
#     score.append([accuracy_score(y_test, y_pred),file])
    score.append([count/l,file])
#     print(df)
score.sort(reverse=True)
print("--------------------------Test : ----------------------------")
for i in range(len(score)):
    print(score[i][1]+" : "+str(score[i][0]))
# df
# Out:
# Acc_w_25_4vuni_66b325&b56522_9.csv : 141 84
# 0.5957446808510638
# At position 1 :  0.2978723404255319
# At position 2 :  0.0851063829787234
# At position 3 :  0.0851063829787234
# At position 4 :  0.1276595744680851
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 241 111
# 0.4605809128630705
# At position 1 :  0.2157676348547718
# At position 2 :  0.11203319502074689
# At position 3 :  0.06639004149377593
# At position 4 :  0.06639004149377593
# Acc_w_25_4vuni_a99828&a99830_9.csv : 100 43
# 0.43
# At position 1 :  0.16
# At position 2 :  0.1
# At position 3 :  0.06
# At position 4 :  0.11
# Acc_w_25_4v_66b325&b56522_9.csv : 141 93
# 0.6595744680851063
# At position 1 :  0.3333333333333333
# At position 2 :  0.11347517730496454
# At position 3 :  0.09219858156028368
# At position 4 :  0.12056737588652482
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 241 118
# 0.4896265560165975
# At position 1 :  0.23236514522821577
# At position 2 :  0.07468879668049792
# At position 3 :  0.07053941908713693
# At position 4 :  0.11203319502074689
# Acc_w_25_4v_a99828&a99830_9.csv : 100 48
# 0.48
# At position 1 :  0.16
# At position 2 :  0.14
# At position 3 :  0.06
# At position 4 :  0.12
# Acc_w_25_window_66b325&b56522_75.csv : 141 89
# 0.6312056737588653
# At position 1 :  0.2765957446808511
# At position 2 :  0.11347517730496454
# At position 3 :  0.12056737588652482
# At position 4 :  0.12056737588652482
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 241 134
# 0.5560165975103735
# At position 1 :  0.27800829875518673
# At position 2 :  0.11203319502074689
# At position 3 :  0.07468879668049792
# At position 4 :  0.0912863070539419
# Acc_w_25_window_a99828&a99830_75.csv : 100 62
# 0.62
# At position 1 :  0.26
# At position 2 :  0.09
# At position 3 :  0.12
# At position 4 :  0.15
# Acc_w_30_4vuni_66b325&b56522_9.csv : 141 93
# 0.6595744680851063
# At position 1 :  0.3262411347517731
# At position 2 :  0.12056737588652482
# At position 3 :  0.1276595744680851
# At position 4 :  0.0851063829787234
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 241 108
# 0.44813278008298757
# At position 1 :  0.2033195020746888
# At position 2 :  0.0954356846473029
# At position 3 :  0.07883817427385892
# At position 4 :  0.07053941908713693
# Acc_w_30_4vuni_a99828&a99830_9.csv : 100 48
# 0.48
# At position 1 :  0.19
# At position 2 :  0.09
# At position 3 :  0.1
# At position 4 :  0.1
# Acc_w_30_4v_66b325&b56522_9.csv : 141 87
# 0.6170212765957447
# At position 1 :  0.28368794326241137
# At position 2 :  0.1702127659574468
# At position 3 :  0.05673758865248227
# At position 4 :  0.10638297872340426
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 241 121
# 0.5020746887966805
# At position 1 :  0.23651452282157676
# At position 2 :  0.1037344398340249
# At position 3 :  0.06639004149377593
# At position 4 :  0.0954356846473029
# Acc_w_30_4v_a99828&a99830_9.csv : 100 55
# 0.55
# At position 1 :  0.21
# At position 2 :  0.12
# At position 3 :  0.14
# At position 4 :  0.08
# Acc_w_30_window_66b325&b56522_90.csv : 141 91
# 0.6453900709219859
# At position 1 :  0.3191489361702128
# At position 2 :  0.1276595744680851
# At position 3 :  0.10638297872340426
# At position 4 :  0.09219858156028368
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 241 124
# 0.5145228215767634
# At position 1 :  0.2697095435684647
# At position 2 :  0.08713692946058091
# At position 3 :  0.06639004149377593
# At position 4 :  0.0912863070539419
# Acc_w_30_window_a99828&a99830_90.csv : 100 56
# 0.56
# At position 1 :  0.24
# At position 2 :  0.11
# At position 3 :  0.07
# At position 4 :  0.14
# Gyro_25_4vuni_66b325&b56522_9.csv : 141 99
# 0.7021276595744681
# At position 1 :  0.375886524822695
# At position 2 :  0.11347517730496454
# At position 3 :  0.10638297872340426
# At position 4 :  0.10638297872340426
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 241 154
# 0.6390041493775933
# At position 1 :  0.2821576763485477
# At position 2 :  0.13278008298755187
# At position 3 :  0.08713692946058091
# At position 4 :  0.13692946058091288
# Gyro_25_4vuni_a99828&a99830_9.csv : 100 65
# 0.65
# At position 1 :  0.34
# At position 2 :  0.16
# At position 3 :  0.06
# At position 4 :  0.09
# Gyro_25_4v_66b325&b56522_9.csv : 141 87
# 0.6170212765957447
# At position 1 :  0.3546099290780142
# At position 2 :  0.07801418439716312
# At position 3 :  0.04964539007092199
# At position 4 :  0.1347517730496454
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 241 139
# 0.5767634854771784
# At position 1 :  0.24481327800829875
# At position 2 :  0.14937759336099585
# At position 3 :  0.07883817427385892
# At position 4 :  0.1037344398340249
# Gyro_25_4v_a99828&a99830_9.csv : 100 51
# 0.51
# At position 1 :  0.23
# At position 2 :  0.1
# At position 3 :  0.08
# At position 4 :  0.1
# Gyro_25_window_66b325&b56522_75.csv : 141 88
# 0.624113475177305
# At position 1 :  0.3262411347517731
# At position 2 :  0.12056737588652482
# At position 3 :  0.05673758865248227
# At position 4 :  0.12056737588652482
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 241 147
# 0.6099585062240664
# At position 1 :  0.2821576763485477
# At position 2 :  0.15352697095435686
# At position 3 :  0.04149377593360996
# At position 4 :  0.13278008298755187
# Gyro_25_window_a99828&a99830_75.csv : 100 71
# 0.71
# At position 1 :  0.37
# At position 2 :  0.14
# At position 3 :  0.08
# At position 4 :  0.12
# Gyro_30_4vuni_66b325&b56522_9.csv : 141 89
# 0.6312056737588653
# At position 1 :  0.36879432624113473
# At position 2 :  0.07092198581560284
# At position 3 :  0.09219858156028368
# At position 4 :  0.09929078014184398
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 241 150
# 0.6224066390041494
# At position 1 :  0.33195020746887965
# At position 2 :  0.13278008298755187
# At position 3 :  0.05394190871369295
# At position 4 :  0.1037344398340249
# Gyro_30_4vuni_a99828&a99830_9.csv : 100 63
# 0.63
# At position 1 :  0.2
# At position 2 :  0.13
# At position 3 :  0.14
# At position 4 :  0.16
# Gyro_30_4v_66b325&b56522_9.csv : 141 87
# 0.6170212765957447
# At position 1 :  0.3404255319148936
# At position 2 :  0.10638297872340426
# At position 3 :  0.06382978723404255
# At position 4 :  0.10638297872340426
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 241 142
# 0.5892116182572614
# At position 1 :  0.3236514522821577
# At position 2 :  0.12448132780082988
# At position 3 :  0.03734439834024896
# At position 4 :  0.1037344398340249
# Gyro_30_4v_a99828&a99830_9.csv : 100 60
# 0.6
# At position 1 :  0.28
# At position 2 :  0.13
# At position 3 :  0.09
# At position 4 :  0.1
# Gyro_30_window_66b325&b56522_90.csv : 141 87
# 0.6170212765957447
# At position 1 :  0.3262411347517731
# At position 2 :  0.09929078014184398
# At position 3 :  0.0851063829787234
# At position 4 :  0.10638297872340426
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 241 156
# 0.6473029045643154
# At position 1 :  0.3651452282157676
# At position 2 :  0.12448132780082988
# At position 3 :  0.06639004149377593
# At position 4 :  0.0912863070539419
# Gyro_30_window_a99828&a99830_90.csv : 100 57
# 0.57
# At position 1 :  0.22
# At position 2 :  0.14
# At position 3 :  0.03
# At position 4 :  0.18
# --------------------------Test : ----------------------------
# Gyro_25_window_a99828&a99830_75.csv : 0.71
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.7021276595744681
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.6595744680851063
# Acc_w_25_4v_66b325&b56522_9.csv : 0.6595744680851063
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.65
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.6473029045643154
# Acc_w_30_window_66b325&b56522_90.csv : 0.6453900709219859
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.6390041493775933
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.6312056737588653
# Acc_w_25_window_66b325&b56522_75.csv : 0.6312056737588653
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.63
# Gyro_25_window_66b325&b56522_75.csv : 0.624113475177305
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.6224066390041494
# Acc_w_25_window_a99828&a99830_75.csv : 0.62
# Gyro_30_window_66b325&b56522_90.csv : 0.6170212765957447
# Gyro_30_4v_66b325&b56522_9.csv : 0.6170212765957447
# Gyro_25_4v_66b325&b56522_9.csv : 0.6170212765957447
# Acc_w_30_4v_66b325&b56522_9.csv : 0.6170212765957447
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.6099585062240664
# Gyro_30_4v_a99828&a99830_9.csv : 0.6
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.5957446808510638
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.5892116182572614
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.5767634854771784
# Gyro_30_window_a99828&a99830_90.csv : 0.57
# Acc_w_30_window_a99828&a99830_90.csv : 0.56
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.5560165975103735
# Acc_w_30_4v_a99828&a99830_9.csv : 0.55
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.5145228215767634
# Gyro_25_4v_a99828&a99830_9.csv : 0.51
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.5020746887966805
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.4896265560165975
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.48
# Acc_w_25_4v_a99828&a99830_9.csv : 0.48
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.4605809128630705
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.44813278008298757
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.43

# %%
# from sklearn.datasets import make_classification
# from sklearn.multioutput import MultiOutputClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.utils import shuffle
# import numpy as np
# X, y1 = make_classification(n_samples=10, n_features=100, n_informative=30, n_classes=3, random_state=1)
# y2 = shuffle(y1, random_state=1)
# y3 = shuffle(y1, random_state=2)
# Y = np.vstack((y1, y2, y3)).T
# n_samples, n_features = X.shape # 10,100
# n_outputs = Y.shape[1] # 3
# n_classes = 3
# print(type(Y))
# print(Y)
# forest = RandomForestClassifier(random_state=1)
# multi_target_forest = MultiOutputClassifier(forest, n_jobs=-1)
# multi_target_forest.fit(X, Y).predict(X)
