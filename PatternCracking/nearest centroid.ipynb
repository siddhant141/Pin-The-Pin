# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestCentroid # 0.32
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Standardized\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    x = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
    logmodel = NearestCentroid()
    logmodel.fit(X_train, y_train)
    y_pred = logmodel.predict(X_train)
    print(file,end=" : ")
    print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
    score.append([accuracy_score(y_test, y_pred),file])
#     print(df)
score.sort(reverse=True)
print("--------------------------Test : ----------------------------")
for i in range(len(score)):
    print(score[i][1]+" : "+str(score[i][0]))
# df
# Out:
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.23333333333333334
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.13055555555555556
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.19666666666666666
# Acc_w_25_4v_66b325&b56522_9.csv : 0.25476190476190474
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.125
# Acc_w_25_4v_a99828&a99830_9.csv : 0.23
# Acc_w_25_window_66b325&b56522_75.csv : 0.26666666666666666
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.12638888888888888
# Acc_w_25_window_a99828&a99830_75.csv : 0.27666666666666667
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.24523809523809523
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.13472222222222222
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.16333333333333333
# Acc_w_30_4v_66b325&b56522_9.csv : 0.2619047619047619
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.12638888888888888
# Acc_w_30_4v_a99828&a99830_9.csv : 0.24666666666666667
# Acc_w_30_window_66b325&b56522_90.csv : 0.25476190476190474
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.125
# Acc_w_30_window_a99828&a99830_90.csv : 0.2966666666666667
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.40476190476190477
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.25833333333333336
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.3
# Gyro_25_4v_66b325&b56522_9.csv : 0.38095238095238093
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.26805555555555555
# Gyro_25_4v_a99828&a99830_9.csv : 0.34
# Gyro_25_window_66b325&b56522_75.csv : 0.3357142857142857
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.2125
# Gyro_25_window_a99828&a99830_75.csv : 0.37
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.40476190476190477
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.275
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.3233333333333333
# Gyro_30_4v_66b325&b56522_9.csv : 0.3904761904761905
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.2861111111111111
# Gyro_30_4v_a99828&a99830_9.csv : 0.35333333333333333
# Gyro_30_window_66b325&b56522_90.csv : 0.34285714285714286
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.24861111111111112
# Gyro_30_window_a99828&a99830_90.csv : 0.38333333333333336
# --------------------------Test : ----------------------------
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.3900709219858156
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.3617021276595745
# Gyro_30_4v_66b325&b56522_9.csv : 0.3262411347517731
# Gyro_25_window_a99828&a99830_75.csv : 0.32
# Gyro_25_4v_66b325&b56522_9.csv : 0.3191489361702128
# Gyro_30_window_66b325&b56522_90.csv : 0.3120567375886525
# Acc_w_30_window_66b325&b56522_90.csv : 0.2978723404255319
# Acc_w_30_4v_66b325&b56522_9.csv : 0.2978723404255319
# Acc_w_25_4v_66b325&b56522_9.csv : 0.2978723404255319
# Acc_w_25_window_66b325&b56522_75.csv : 0.2907801418439716
# Gyro_25_window_66b325&b56522_75.csv : 0.28368794326241137
# Gyro_30_window_a99828&a99830_90.csv : 0.28
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.2765957446808511
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.2695035460992908
# Gyro_25_4v_a99828&a99830_9.csv : 0.26
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.25
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.23236514522821577
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.22821576763485477
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.22406639004149378
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.22406639004149378
# Gyro_30_4v_a99828&a99830_9.csv : 0.22
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.21161825726141079
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.1908713692946058
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.16
# Acc_w_30_window_a99828&a99830_90.csv : 0.15
# Acc_w_25_window_a99828&a99830_75.csv : 0.15
# Acc_w_25_4v_a99828&a99830_9.csv : 0.14
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.12033195020746888
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.12033195020746888
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.12033195020746888
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.11618257261410789
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.11203319502074689
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.11203319502074689
# Acc_w_30_4v_a99828&a99830_9.csv : 0.1
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.1
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.09
