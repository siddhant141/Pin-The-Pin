# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import concurrent.futures

# %%
foldertype="Acc_wGyro"
folder="Acc_w"
folderg="Gyro"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Uni\\"+folder+"\\"
pathg="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Uni\\"+folderg+"\\"
pathex=[]
pathexg=[]
temp = [f for f in listdir(path) if isfile(join(path, f))]
tempg = [f for f in listdir(pathg) if isfile(join(pathg, f))]
files=["4b0c19"]
for i in range(len(temp)):
    st=temp[i]
    if(os.path.getsize(path+st)<4096):
        continue
    if(temp[i][:6] in files):
        pathex.append(temp[i])
for i in range(len(tempg)):
    st=tempg[i]
    if(os.path.getsize(pathg+st)<4096):
        continue
    if(tempg[i][:6] in files):
        pathexg.append(tempg[i])
#     if(files[0]=="all"):
#         pathex.append(temp[i])
# print(pathex)
print(len(temp))
print(len(tempg))
print(len(pathex))
print(len(pathexg))
# Out:
# 273
# 273
# 273
# 273

# %%
# folder_n_no.ofvalues_no.offiles_keycolno.
propath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Processed\\"
def savefile():
    df.to_csv (propath+foldertype+"_"+str(n)+"_"+fcode+"_"+"&".join(files)+"_"+str(keypos)+".csv", index = False, header=True)

# %%
def acc4v(i):
    try:
        dff=pd.read_csv(path+pathex[i])
        
        keydt=pathex[i].rfind("_")+4
        minkeyd=int(pathex[i][keydt:-4])
        
        dff=dff.head(minkeyd + int((nn)/2) -1)
#         dff=dff.head(minkeyu)
        dff=dff.tail(nn)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")        
        return dff
    except:
        print("error : ",pathex[i])
#         traceback.print_exc()

# %%
#taking window, removing init (avg 300), uniform values
# n -> number of lines in csv file
# actual -> the actual key pressed
# minkeyd -> index of nearest key down time
# minkeyu -> index of nearest key up time
# keydt -> key down time from file name
# keyut -> key up time from file name
fcode="winuni"
nn=200
n=400+nn
keypos=1
actual=1
df=pd.read_csv(pathg+pathexg[0])
for i in range(len(pathex)):
    try:
        dff=pd.read_csv(pathg+pathexg[i])
        
        keydt=pathexg[i].rfind("_")+4
        minkeyd=int(pathexg[i][keydt:-4])
        
        dff=dff.head(minkeyd + int((n-nn)/2) -1)
#         dff=dff.head(minkeyu)
        dff=dff.tail(n-nn)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")
        
        df1=acc4v(i)
        dff=dff.append(df1,ignore_index=True)
        
        df1=dff.stack().swaplevel()        
        df1.index=df1.index.map('{0[0]}_{0[1]}'.format) 
        dff=df1.to_frame().T
        ind=pathexg[i].rfind("_")+3
        print(i,pathexg[i])
        dff.insert(n*3, "key", int(pathexg[i][ind]))
        keypos=n*3
        if(i==0):
            df=dff
        else:
            df=df.append(dff,ignore_index = True)
    except:
        print("error : ",pathexg[i])
#         traceback.print_exec()
        continue
print(df.index[-1])
# Out:
# 0 4b0c19-04-2020_03_49_01_PM0865.csv
# 1 4b0c19-04-2020_03_49_03_PM1645.csv
# 2 4b0c19-04-2020_03_49_04_PM2469.csv
# 3 4b0c19-04-2020_03_49_05_PM3456.csv
# 4 4b0c19-04-2020_03_49_06_PM4441.csv
# 5 4b0c19-04-2020_03_49_07_PM5397.csv
# 6 4b0c19-04-2020_03_49_08_PM6463.csv
# 7 4b0c19-04-2020_03_49_09_PM7351.csv
# 8 4b0c19-04-2020_03_49_10_PM8673.csv
# 9 4b0c19-04-2020_03_49_11_PM9538.csv
# 10 4b0c19-04-2020_03_49_12_PM0200.csv
# error :  4b0c19-04-2020_03_49_12_PM0200.csv
# 11 4b0c19-04-2020_03_49_14_PM2633.csv
# 12 4b0c19-04-2020_03_49_15_PM4720.csv
# 13 4b0c19-04-2020_03_49_16_PM6505.csv
# 14 4b0c19-04-2020_03_49_17_PM8581.csv
# 15 4b0c19-04-2020_03_49_19_PM0876.csv
# 16 4b0c19-04-2020_03_49_20_PM3851.csv
# 17 4b0c19-04-2020_03_49_22_PM5639.csv
# 18 4b0c19-04-2020_03_49_23_PM7489.csv
# 19 4b0c19-04-2020_03_49_24_PM9568.csv
# 20 4b0c19-04-2020_03_49_25_PM1801.csv
# 21 4b0c19-04-2020_03_49_27_PM3762.csv
# 22 4b0c19-04-2020_03_49_28_PM6588.csv
# 23 4b0c19-04-2020_03_49_29_PM9568.csv
# 24 4b0c19-04-2020_03_49_31_PM2934.csv
# 25 4b0c19-04-2020_03_49_32_PM5609.csv
# 26 4b0c19-04-2020_03_49_33_PM8750.csv
# 27 4b0c19-04-2020_03_49_35_PM1718.csv
# 28 4b0c19-04-2020_03_49_36_PM4721.csv
# 29 4b0c19-04-2020_03_49_38_PM7380.csv
# 30 4b0c19-04-2020_03_49_39_PM0526.csv
# 31 4b0c19-04-2020_03_49_40_PM4852.csv
# 32 4b0c19-04-2020_03_49_42_PM8497.csv
# 33 4b0c19-04-2020_03_49_43_PM2727.csv
# 34 4b0c19-04-2020_03_49_45_PM6662.csv
# 35 4b0c19-04-2020_03_49_46_PM0532.csv
# 36 4b0c19-04-2020_03_49_47_PM5689.csv
# 37 4b0c19-04-2020_03_49_49_PM9678.csv
# 38 4b0c19-04-2020_03_49_50_PM3708.csv
# 39 4b0c19-04-2020_03_49_51_PM7718.csv
# 40 4b0c19-04-2020_03_49_53_PM1724.csv
# 41 4b0c19-04-2020_03_49_54_PM5515.csv
# 42 4b0c19-04-2020_03_49_55_PM0495.csv
# 43 4b0c19-04-2020_03_49_57_PM6771.csv
# 44 4b0c19-04-2020_03_49_58_PM1667.csv
# 45 4b0c19-04-2020_03_49_59_PM6548.csv
# 46 4b0c19-04-2020_03_50_01_PM2778.csv
# 47 4b0c19-04-2020_03_50_02_PM7682.csv
# 48 4b0c19-04-2020_03_50_04_PM2607.csv
# 49 4b0c19-04-2020_03_50_05_PM8854.csv
# 50 4b0c19-04-2020_03_50_07_PM3698.csv
# 51 4b0c19-04-2020_03_50_08_PM8899.csv
# 52 4b0c19-04-2020_03_50_09_PM4667.csv
# 53 4b0c19-04-2020_03_50_11_PM9408.csv
# 54 4b0c19-04-2020_03_50_12_PM4677.csv
# 55 4b0c19-04-2020_03_50_13_PM0524.csv
# 56 4b0c19-04-2020_03_50_15_PM7688.csv
# 57 4b0c19-04-2020_03_50_16_PM3747.csv
# 58 4b0c19-04-2020_03_50_17_PM9530.csv
# 59 4b0c19-04-2020_03_50_19_PM5867.csv
# 60 4b0c19-04-2020_03_50_20_PM1838.csv
# 61 4b0c19-04-2020_03_50_22_PM7481.csv
# 62 4b0c19-04-2020_03_50_23_PM4798.csv
# 63 4b0c19-04-2020_03_50_24_PM1746.csv
# 64 4b0c19-04-2020_03_50_26_PM8466.csv
# 65 4b0c19-04-2020_03_50_27_PM5621.csv
# 66 4b0c19-04-2020_03_50_28_PM2681.csv
# 67 4b0c19-04-2020_03_50_30_PM9499.csv
# 68 4b0c19-04-2020_03_50_31_PM6728.csv
# 69 4b0c19-04-2020_03_50_33_PM3828.csv
# 70 4b0c19-04-2020_03_50_34_PM0516.csv
# 71 4b0c19-04-2020_03_50_36_PM8899.csv
# 72 4b0c19-04-2020_03_50_37_PM6773.csv
# 73 4b0c19-04-2020_03_50_39_PM4818.csv
# 74 4b0c19-04-2020_03_50_40_PM2792.csv
# 75 4b0c19-04-2020_03_50_41_PM0478.csv
# 76 4b0c19-04-2020_03_50_43_PM9692.csv
# 77 4b0c19-04-2020_03_50_44_PM7716.csv
# 78 4b0c19-04-2020_03_50_46_PM5924.csv
# 79 4b0c19-04-2020_03_50_47_PM3704.csv
# 80 4b0c19-04-2020_03_50_49_PM1814.csv
# 81 4b0c19-04-2020_03_50_50_PM9306.csv
# 82 4b0c19-04-2020_03_50_51_PM8777.csv
# 83 4b0c19-04-2020_03_50_53_PM7769.csv
# 84 4b0c19-04-2020_03_50_54_PM6811.csv
# 85 4b0c19-04-2020_03_50_56_PM5751.csv
# 86 4b0c19-04-2020_03_50_57_PM4693.csv
# 87 4b0c19-04-2020_03_50_58_PM3715.csv
# 88 4b0c19-04-2020_03_51_00_PM2591.csv
# 89 4b0c19-04-2020_03_51_01_PM1876.csv
# 90 4b0c19-04-2020_03_51_02_PM0216.csv
# 91 4b0c19-04-2020_03_51_21_PM0116.csv
# error :  4b0c19-04-2020_03_51_21_PM0116.csv
# 92 4b0c19-04-2020_03_51_22_PM1545.csv
# 93 4b0c19-04-2020_03_51_23_PM2493.csv
# 94 4b0c19-04-2020_03_51_24_PM3427.csv
# 95 4b0c19-04-2020_03_51_25_PM4367.csv
# 96 4b0c19-04-2020_03_51_26_PM5288.csv
# 97 4b0c19-04-2020_03_51_27_PM6417.csv
# 98 4b0c19-04-2020_03_51_28_PM7332.csv
# 99 4b0c19-04-2020_03_51_29_PM8321.csv
# 100 4b0c19-04-2020_03_51_31_PM9717.csv
# 101 4b0c19-04-2020_03_51_32_PM0806.csv
# 102 4b0c19-04-2020_03_51_33_PM2729.csv
# 103 4b0c19-04-2020_03_51_35_PM4496.csv
# 104 4b0c19-04-2020_03_51_36_PM6169.csv
# error :  4b0c19-04-2020_03_51_36_PM6169.csv
# 105 4b0c19-04-2020_03_51_37_PM8968.csv
# 106 4b0c19-04-2020_03_51_38_PM0377.csv
# 107 4b0c19-04-2020_03_51_40_PM3682.csv
# 108 4b0c19-04-2020_03_51_41_PM5500.csv
# 109 4b0c19-04-2020_03_51_42_PM7530.csv
# 110 4b0c19-04-2020_03_51_43_PM9852.csv
# 111 4b0c19-04-2020_03_51_45_PM1855.csv
# 112 4b0c19-04-2020_03_51_46_PM3495.csv
# 113 4b0c19-04-2020_03_51_48_PM6603.csv
# 114 4b0c19-04-2020_03_51_49_PM9731.csv
# 115 4b0c19-04-2020_03_51_50_PM2747.csv
# 116 4b0c19-04-2020_03_51_52_PM5652.csv
# 117 4b0c19-04-2020_03_51_53_PM8512.csv
# 118 4b0c19-04-2020_03_51_54_PM1718.csv
# 119 4b0c19-04-2020_03_51_56_PM4668.csv
# 120 4b0c19-04-2020_03_51_57_PM71234.csv
# 121 4b0c19-04-2020_03_51_58_PM0711.csv
# 122 4b0c19-04-2020_03_52_00_PM4682.csv
# 123 4b0c19-04-2020_03_52_01_PM8696.csv
# 124 4b0c19-04-2020_03_52_02_PM2687.csv
# 125 4b0c19-04-2020_03_52_04_PM6678.csv
# 126 4b0c19-04-2020_03_52_05_PM0608.csv
# 127 4b0c19-04-2020_03_52_06_PM5679.csv
# 128 4b0c19-04-2020_03_52_08_PM9128.csv
# error :  4b0c19-04-2020_03_52_08_PM9128.csv
# 129 4b0c19-04-2020_03_52_09_PM3770.csv
# 130 4b0c19-04-2020_03_52_11_PM7669.csv
# 131 4b0c19-04-2020_03_52_12_PM1629.csv
# 132 4b0c19-04-2020_03_52_13_PM5633.csv
# 133 4b0c19-04-2020_03_52_15_PM0511.csv
# 134 4b0c19-04-2020_03_52_16_PM6768.csv
# 135 4b0c19-04-2020_03_52_17_PM1672.csv
# 136 4b0c19-04-2020_03_52_19_PM6407.csv
# 137 4b0c19-04-2020_03_52_20_PM2633.csv
# 138 4b0c19-04-2020_03_52_21_PM7672.csv
# 139 4b0c19-04-2020_03_52_23_PM2660.csv
# 140 4b0c19-04-2020_03_52_24_PM8490.csv
# 141 4b0c19-04-2020_03_52_25_PM3695.csv
# 142 4b0c19-04-2020_03_52_27_PM8679.csv
# 143 4b0c19-04-2020_03_52_28_PM4644.csv
# 144 4b0c19-04-2020_03_52_29_PM9753.csv
# 145 4b0c19-04-2020_03_52_31_PM4675.csv
# 146 4b0c19-04-2020_03_52_32_PM0465.csv
# 147 4b0c19-04-2020_03_52_33_PM7647.csv
# 148 4b0c19-04-2020_03_52_35_PM3761.csv
# 149 4b0c19-04-2020_03_52_36_PM9697.csv
# 150 4b0c19-04-2020_03_52_37_PM5609.csv
# 151 4b0c19-04-2020_03_52_39_PM11093.csv
# 152 4b0c19-04-2020_03_52_41_PM7537.csv
# 153 4b0c19-04-2020_03_52_42_PM4832.csv
# 154 4b0c19-04-2020_03_52_44_PM1730.csv
# 155 4b0c19-04-2020_03_52_45_PM8400.csv
# 156 4b0c19-04-2020_03_52_46_PM5842.csv
# 157 4b0c19-04-2020_03_52_48_PM21000.csv
# 158 4b0c19-04-2020_03_52_50_PM9792.csv
# 159 4b0c19-04-2020_03_52_51_PM61114.csv
# 160 4b0c19-04-2020_03_52_53_PM3694.csv
# 161 4b0c19-04-2020_03_52_54_PM0722.csv
# 162 4b0c19-04-2020_03_52_55_PM8680.csv
# 163 4b0c19-04-2020_03_52_57_PM6693.csv
# 164 4b0c19-04-2020_03_52_58_PM4680.csv
# 165 4b0c19-04-2020_03_52_59_PM2627.csv
# 166 4b0c19-04-2020_03_53_01_PM0531.csv
# 167 4b0c19-04-2020_03_53_02_PM9801.csv
# 168 4b0c19-04-2020_03_53_03_PM7685.csv
# 169 4b0c19-04-2020_03_53_05_PM5813.csv
# 170 4b0c19-04-2020_03_53_06_PM3703.csv
# 171 4b0c19-04-2020_03_53_08_PM1710.csv
# 172 4b0c19-04-2020_03_53_09_PM9203.csv
# 173 4b0c19-04-2020_03_53_10_PM8856.csv
# 174 4b0c19-04-2020_03_53_12_PM7669.csv
# 175 4b0c19-04-2020_03_53_13_PM6824.csv
# 176 4b0c19-04-2020_03_53_15_PM5692.csv
# 177 4b0c19-04-2020_03_53_16_PM4644.csv
# 178 4b0c19-04-2020_03_53_17_PM3588.csv
# 179 4b0c19-04-2020_03_53_18_PM2641.csv
# 180 4b0c19-04-2020_03_53_20_PM1427.csv
# 181 4b0c19-04-2020_03_53_21_PM0166.csv
# error :  4b0c19-04-2020_03_53_21_PM0166.csv
# 182 4b0c19-04-2020_03_53_32_PM0599.csv
# 183 4b0c19-04-2020_03_53_33_PM1476.csv
# 184 4b0c19-04-2020_03_53_34_PM2399.csv
# 185 4b0c19-04-2020_03_53_36_PM3581.csv
# 186 4b0c19-04-2020_03_53_37_PM4370.csv
# 187 4b0c19-04-2020_03_53_38_PM5579.csv
# 188 4b0c19-04-2020_03_53_39_PM6518.csv
# 189 4b0c19-04-2020_03_53_40_PM7642.csv
# 190 4b0c19-04-2020_03_53_42_PM8660.csv
# 191 4b0c19-04-2020_03_53_43_PM9589.csv
# 192 4b0c19-04-2020_03_53_44_PM0681.csv
# 193 4b0c19-04-2020_03_53_45_PM2656.csv
# 194 4b0c19-04-2020_03_53_47_PM4761.csv
# 195 4b0c19-04-2020_03_53_48_PM6645.csv
# 196 4b0c19-04-2020_03_53_49_PM8697.csv
# 197 4b0c19-04-2020_03_53_51_PM0544.csv
# 198 4b0c19-04-2020_03_53_52_PM3625.csv
# 199 4b0c19-04-2020_03_53_53_PM5867.csv
# 200 4b0c19-04-2020_03_53_55_PM7687.csv
# 201 4b0c19-04-2020_03_53_56_PM9816.csv
# 202 4b0c19-04-2020_03_53_58_PM11464.csv
# 203 4b0c19-04-2020_03_54_00_PM3864.csv
# 204 4b0c19-04-2020_03_54_01_PM6649.csv
# 205 4b0c19-04-2020_03_54_02_PM9693.csv
# 206 4b0c19-04-2020_03_54_04_PM2796.csv
# 207 4b0c19-04-2020_03_54_05_PM5646.csv
# 208 4b0c19-04-2020_03_54_06_PM8671.csv
# 209 4b0c19-04-2020_03_54_08_PM1686.csv
# 210 4b0c19-04-2020_03_54_09_PM4665.csv
# 211 4b0c19-04-2020_03_54_10_PM7627.csv
# 212 4b0c19-04-2020_03_54_12_PM0690.csv
# 213 4b0c19-04-2020_03_54_13_PM4627.csv
# 214 4b0c19-04-2020_03_54_14_PM8704.csv
# 215 4b0c19-04-2020_03_54_16_PM2636.csv
# 216 4b0c19-04-2020_03_54_17_PM6608.csv
# 217 4b0c19-04-2020_03_54_18_PM0460.csv
# 218 4b0c19-04-2020_03_54_20_PM5676.csv
# 219 4b0c19-04-2020_03_54_21_PM9708.csv
# 220 4b0c19-04-2020_03_54_22_PM3688.csv
# 221 4b0c19-04-2020_03_54_24_PM7730.csv
# 222 4b0c19-04-2020_03_54_25_PM1696.csv
# 223 4b0c19-04-2020_03_54_26_PM5620.csv
# 224 4b0c19-04-2020_03_54_27_PM0614.csv
# 225 4b0c19-04-2020_03_54_29_PM6456.csv
# 226 4b0c19-04-2020_03_54_30_PM1626.csv
# 227 4b0c19-04-2020_03_54_31_PM6600.csv
# 228 4b0c19-04-2020_03_54_33_PM2655.csv
# 229 4b0c19-04-2020_03_54_34_PM7616.csv
# 230 4b0c19-04-2020_03_54_35_PM2752.csv
# 231 4b0c19-04-2020_03_54_36_PM8776.csv
# 232 4b0c19-04-2020_03_54_38_PM3629.csv
# 233 4b0c19-04-2020_03_54_39_PM8636.csv
# 234 4b0c19-04-2020_03_54_40_PM4701.csv
# 235 4b0c19-04-2020_03_54_42_PM9532.csv
# 236 4b0c19-04-2020_03_54_43_PM4658.csv
# 237 4b0c19-04-2020_03_54_44_PM0375.csv
# 238 4b0c19-04-2020_03_54_46_PM7715.csv
# 239 4b0c19-04-2020_03_54_47_PM3702.csv
# 240 4b0c19-04-2020_03_54_48_PM9678.csv
# 241 4b0c19-04-2020_03_54_49_PM5612.csv
# 242 4b0c19-04-2020_03_54_51_PM1603.csv
# 243 4b0c19-04-2020_03_54_52_PM7676.csv
# 244 4b0c19-04-2020_03_54_53_PM4629.csv
# 245 4b0c19-04-2020_03_54_54_PM1622.csv
# 246 4b0c19-04-2020_03_54_56_PM8467.csv
# 247 4b0c19-04-2020_03_54_57_PM5646.csv
# 248 4b0c19-04-2020_03_54_58_PM2603.csv
# 249 4b0c19-04-2020_03_55_00_PM9667.csv
# 250 4b0c19-04-2020_03_55_01_PM6660.csv
# 251 4b0c19-04-2020_03_55_02_PM3648.csv
# 252 4b0c19-04-2020_03_55_04_PM0413.csv
# 253 4b0c19-04-2020_03_55_05_PM8452.csv
# 254 4b0c19-04-2020_03_55_06_PM6645.csv
# 255 4b0c19-04-2020_03_55_08_PM4708.csv
# 256 4b0c19-04-2020_03_55_09_PM2634.csv
# 257 4b0c19-04-2020_03_55_10_PM0394.csv
# 258 4b0c19-04-2020_03_55_11_PM9674.csv
# 259 4b0c19-04-2020_03_55_13_PM7631.csv
# 260 4b0c19-04-2020_03_55_14_PM5730.csv
# 261 4b0c19-04-2020_03_55_15_PM3598.csv
# 262 4b0c19-04-2020_03_55_17_PM1683.csv
# 263 4b0c19-04-2020_03_55_18_PM9723.csv
# 264 4b0c19-04-2020_03_55_19_PM8773.csv
# 265 4b0c19-04-2020_03_55_21_PM7750.csv
# 266 4b0c19-04-2020_03_55_22_PM6788.csv
# 267 4b0c19-04-2020_03_55_23_PM5712.csv
# 268 4b0c19-04-2020_03_55_25_PM4563.csv
# 269 4b0c19-04-2020_03_55_26_PM3535.csv
# 270 4b0c19-04-2020_03_55_27_PM2581.csv
# 271 4b0c19-04-2020_03_55_28_PM1529.csv
# 272 4b0c19-04-2020_03_55_29_PM012.csv
# error :  4b0c19-04-2020_03_55_29_PM012.csv
# 266

# %%
savefile()
