# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier # NN. very much useful and hidden layers. 0.31
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Using\\"
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    x = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
#     sc = StandardScaler()
#     X_train = sc.fit_transform(X_train)
#     X_test = sc.transform(X_test)
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity",hidden_layer_sizes=(800,10))
    logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity")
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=1500,warm_start=True,activation="identity")
    logmodel.fit(X_train, y_train)
#     y_pred = logmodel.predict(X_train)
#     print(file,end=" : ")
#     print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    
    p = logmodel.predict_proba(X_test)
    nn = 3
    top_n = np.argsort(p)[:,:-nn-1:-1]
#     for i in range(len(y_test)):
#         print(y_test[i],top_n[i])
    count=0
    count1=0
    count2=0
    count3=0
    count12=0
    for i in range(len(y_pred)):
        if(y_test[i] in top_n[i]):
            count+=1
        if(y_test[i] in top_n[i][:2]):
            count12+=1
        if(y_test[i] == top_n[i][0]):
            count1+=1
        elif(y_test[i] == top_n[i][1]):
            count2+=1
        elif(y_test[i] == top_n[i][2]):
            count3+=1
#         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(file)
    print(l,count)
    print("Any one : ",count/l)
    print("At position 1 and 2 : ",count12/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
    
#     df = pd.DataFrame({'Actual': y_test, 'Predicted': top_n})
    
#     print(df)
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
    score.append([accuracy_score(y_test, y_pred),file,count12/l])
#     score.append([count/l,file])
#     score12.append([count12/l,file])
    
#     df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
#     score.append([accuracy_score(y_test, y_pred),file])
#     print(df)
# score.sort(reverse=True)
# score12.sort(reverse=True)
print("----------------------------------------------Test : --------------------------------------")
for i in range(len(score)):
#     print(score[i][1]+" : "+str(score[i][0]))
    print(score[i][1])
for i in range(len(score)):
    print(score[i][0])
print("------------------------------------------2nd guess : ---------------------------------------------")
for i in range(len(score)):
    print(score[i][2])
# print("------------------------------------------Test : ----------------------------------------")
# for i in range(len(score)):
#     print(score12[i][1]+" : "+str(score12[i][0]))
# df
# Out:
# Acc_wo_200_winuni_4b0c17&4b0c18_600.csv
# 683 514
# Any one :  0.7525622254758418
# At position 1 and 2 :  0.6295754026354319
# At position 1 :  0.3953147877013177
# At position 2 :  0.2342606149341142
# At position 3 :  0.12298682284040996
# Acc_wo_400_winuni_4b0c17&4b0c18_1200.csv
# 679 535
# Any one :  0.7879234167893961
# At position 1 and 2 :  0.6745213549337261
# At position 1 :  0.4477172312223859
# At position 2 :  0.2268041237113402
# At position 3 :  0.1134020618556701
# Gyro_200_winuni_4b0c17&4b0c18_600.csv
# 683 576
# Any one :  0.8433382137628112
# At position 1 and 2 :  0.7408491947291361
# At position 1 :  0.5065885797950219
# At position 2 :  0.2342606149341142
# At position 3 :  0.10248901903367497

# %%
# # save trained model
# for file in pathex:
#     ni=file.rfind("_")+1
#     n=int(file[ni:].split(".")[0])
#     df=pd.read_csv(path+file)
#     X = df.iloc[:, 0:n].values
#     y = df.iloc[:, n].values
#     X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#     #Create KNN Classifier
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=1500,warm_start=True,activation="identity")
#     logmodel.fit(X_train, y_train)
#     filename = "zmlp_"+file[:-4]+".sav"
#     pickle.dump(logmodel, open(modelpath+filename, 'wb'))
