# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.multioutput import MultiOutputClassifier
# from sklearn.linear_model import LogisticRegressionCV #0.32. maybe few options in here too
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
# pathm="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
pathm="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"
pathmex = [f for f in listdir(pathm) if isfile(join(pathm, f))]
pathmex.sort()
# pathex=["Gyro_400_window_a29c08&66b325&b56522_1200.csv"]
# filem=pathmex[0]

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Testing\\"
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Testing\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
# file=pathex[0]
for filem in pathmex:
    for file in pathex:
        ni=file.rfind("_")+1
        n=int(file[ni:].split(".")[0])
        nim=filem.rfind("_")+1
        nm=int(filem[nim:].split(".")[0])
        if(n!=nm):
            continue
        df=pd.read_csv(path+file)
        x_test = df.iloc[:, 0:n].values
        y_test = df.iloc[:, n].values
        # X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=1, random_state=0)
        logmodel=pickle.load(open(pathm+filem, 'rb'))
#         X_train, x_test, y_train, y_test = train_test_split(x_test, y_test, test_size=0.3, random_state=0)
#         logmodel.fit(X_train, y_train)
#         result = logmodel.score(X_test, Y_test)
#         print(result)
#         print(x_test)
        y_pred = logmodel.predict(x_test)
        df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

        # print(y_pred,y)

        p = logmodel.predict_proba(x_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        count=0
        count12=0
        for i in range(len(y_pred)):
            if(y_test[i] in top_n[i]):
                count+=1
            if(y_test[i] in top_n[i][:2]):
                count12+=1
    #         print(y_test[i],top_n[i])
        l=len(y_pred)
        print(filem)
        print(file)
        print("f1score : ",f1_score(y_test, y_pred, average="micro"))
        print("accuracy score : ", accuracy_score(y_test,y_pred))
        print(count/l)
        print("At position 1 or 2 : ",count12/l)
        print(classification_report(y_test, y_pred))
# Out:
# logistic500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.5384615384615384
# accuracy score :  0.5384615384615384
# 0.8937728937728938
# At position 1 or 2 :  0.7838827838827839
#               precision    recall  f1-score   support
#
#            0       0.65      0.43      0.52        30
#            1       0.71      0.89      0.79        27
#            2       0.73      0.59      0.65        27
#            3       0.55      0.78      0.65        27
#            4       0.52      0.48      0.50        27
#            5       0.35      0.63      0.45        27
#            6       0.42      0.19      0.26        27
#            7       0.61      0.63      0.62        27
#            8       0.42      0.19      0.26        27
#            9       0.47      0.59      0.52        27
#
#     accuracy                           0.54       273
#    macro avg       0.54      0.54      0.52       273
# weighted avg       0.54      0.54      0.52       273
#
# logistic500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.3023255813953488
# At position 1 or 2 :  0.20155038759689922
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.10      1.00      0.18        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# logistic500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.06976744186046512
# accuracy score :  0.06976744186046512
# 0.24031007751937986
# At position 1 or 2 :  0.16279069767441862
#               precision    recall  f1-score   support
#
#            0       0.05      0.10      0.07        29
#            1       0.08      0.08      0.08        26
#            2       0.00      0.00      0.00        26
#            3       0.07      0.16      0.10        25
#            4       0.00      0.00      0.00        24
#            5       0.17      0.16      0.17        25
#            6       0.00      0.00      0.00        25
#            7       0.08      0.04      0.05        25
#            8       0.05      0.08      0.06        26
#            9       0.09      0.07      0.08        27
#
#     accuracy                           0.07       258
#    macro avg       0.06      0.07      0.06       258
# weighted avg       0.06      0.07      0.06       258
#
# logistic500_Acc_wGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_window_4b0c19_1800.csv
# f1score :  0.5852713178294574
# accuracy score :  0.5852713178294574
# 0.8992248062015504
# At position 1 or 2 :  0.8062015503875969
#               precision    recall  f1-score   support
#
#            0       0.67      0.55      0.60        29
#            1       0.67      0.92      0.77        26
#            2       0.68      0.73      0.70        26
#            3       0.65      0.60      0.63        25
#            4       0.56      0.42      0.48        24
#            5       0.44      0.72      0.55        25
#            6       0.46      0.44      0.45        25
#            7       0.88      0.60      0.71        25
#            8       0.46      0.42      0.44        26
#            9       0.52      0.44      0.48        27
#
#     accuracy                           0.59       258
#    macro avg       0.60      0.58      0.58       258
# weighted avg       0.60      0.59      0.58       258
#
# logistic500_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c19_2400.csv
# f1score :  0.5
# accuracy score :  0.5
# 0.875968992248062
# At position 1 or 2 :  0.7751937984496124
#               precision    recall  f1-score   support
#
#            0       0.67      0.48      0.56        29
#            1       0.74      0.88      0.81        26
#            2       0.54      0.58      0.56        26
#            3       0.42      0.52      0.46        25
#            4       0.48      0.50      0.49        24
#            5       0.40      0.40      0.40        25
#            6       0.35      0.32      0.33        25
#            7       0.68      0.52      0.59        25
#            8       0.35      0.42      0.39        26
#            9       0.42      0.37      0.39        27
#
#     accuracy                           0.50       258
#    macro avg       0.50      0.50      0.50       258
# weighted avg       0.51      0.50      0.50       258
#
# logistic500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.0989010989010989
# accuracy score :  0.0989010989010989
# 0.2857142857142857
# At position 1 or 2 :  0.1978021978021978
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.00      0.00      0.00        27
#            2       0.10      1.00      0.19        27
#            3       0.00      0.00      0.00        27
#            4       0.00      0.00      0.00        27
#            5       0.00      0.00      0.00        27
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00        27
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       273
#    macro avg       0.01      0.10      0.02       273
# weighted avg       0.01      0.10      0.02       273
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# logistic500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.4728682170542635
# accuracy score :  0.4728682170542636
# 0.8255813953488372
# At position 1 or 2 :  0.7054263565891473
#               precision    recall  f1-score   support
#
#            0       0.62      0.52      0.57        29
#            1       0.69      0.85      0.76        26
#            2       0.48      0.58      0.53        26
#            3       0.40      0.48      0.44        25
#            4       0.47      0.33      0.39        24
#            5       0.36      0.40      0.38        25
#            6       0.30      0.32      0.31        25
#            7       0.68      0.52      0.59        25
#            8       0.41      0.35      0.38        26
#            9       0.36      0.37      0.36        27
#
#     accuracy                           0.47       258
#    macro avg       0.48      0.47      0.47       258
# weighted avg       0.48      0.47      0.47       258
#
# logistic500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.2441860465116279
# At position 1 or 2 :  0.16279069767441862
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.21      0.62      0.32        26
#            2       0.10      0.04      0.06        26
#            3       0.05      0.24      0.08        25
#            4       0.00      0.00      0.00        24
#            5       0.17      0.04      0.06        25
#            6       0.17      0.04      0.06        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.09      0.04      0.05        27
#
#     accuracy                           0.10       258
#    macro avg       0.08      0.10      0.06       258
# weighted avg       0.08      0.10      0.06       258
#
# logistic500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.10989010989010989
# accuracy score :  0.10989010989010989
# 0.3076923076923077
# At position 1 or 2 :  0.2087912087912088
#               precision    recall  f1-score   support
#
#            0       0.11      1.00      0.20        30
#            1       0.00      0.00      0.00        27
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        27
#            4       0.00      0.00      0.00        27
#            5       0.00      0.00      0.00        27
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00        27
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.11       273
#    macro avg       0.01      0.10      0.02       273
# weighted avg       0.01      0.11      0.02       273
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# logistic500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.09689922480620156
# accuracy score :  0.09689922480620156
# 0.29844961240310075
# At position 1 or 2 :  0.20155038759689922
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.00      0.00      0.00        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.10      1.00      0.18        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# logistic500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.5155038759689923
# accuracy score :  0.5155038759689923
# 0.8837209302325582
# At position 1 or 2 :  0.7829457364341085
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55        29
#            1       0.65      0.85      0.73        26
#            2       0.62      0.62      0.62        26
#            3       0.53      0.76      0.62        25
#            4       0.55      0.50      0.52        24
#            5       0.38      0.40      0.39        25
#            6       0.43      0.24      0.31        25
#            7       0.75      0.60      0.67        25
#            8       0.27      0.27      0.27        26
#            9       0.43      0.33      0.38        27
#
#     accuracy                           0.52       258
#    macro avg       0.51      0.52      0.51       258
# weighted avg       0.51      0.52      0.51       258
#
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.6373626373626373
# accuracy score :  0.6373626373626373
# 0.9377289377289377
# At position 1 or 2 :  0.9010989010989011
#               precision    recall  f1-score   support
#
#            0       0.67      0.60      0.63        30
#            1       0.73      0.89      0.80        27
#            2       0.70      0.70      0.70        27
#            3       0.58      0.67      0.62        27
#            4       0.59      0.63      0.61        27
#            5       0.61      0.70      0.66        27
#            6       0.52      0.41      0.46        27
#            7       0.69      0.67      0.68        27
#            8       0.54      0.48      0.51        27
#            9       0.71      0.63      0.67        27
#
#     accuracy                           0.64       273
#    macro avg       0.63      0.64      0.63       273
# weighted avg       0.63      0.64      0.63       273
#
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.10852713178294573
# accuracy score :  0.10852713178294573
# 0.3178294573643411
# At position 1 or 2 :  0.22093023255813954
#               precision    recall  f1-score   support
#
#            0       0.12      0.90      0.20        29
#            1       0.00      0.00      0.00        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.06      0.07      0.07        27
#
#     accuracy                           0.11       258
#    macro avg       0.02      0.10      0.03       258
# weighted avg       0.02      0.11      0.03       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.05426356589147287
# accuracy score :  0.05426356589147287
# 0.25193798449612403
# At position 1 or 2 :  0.1511627906976744
#               precision    recall  f1-score   support
#
#            0       0.04      0.10      0.05        29
#            1       0.00      0.00      0.00        26
#            2       0.00      0.00      0.00        26
#            3       0.08      0.08      0.08        25
#            4       0.00      0.00      0.00        24
#            5       0.21      0.12      0.15        25
#            6       0.00      0.00      0.00        25
#            7       0.14      0.04      0.06        25
#            8       0.08      0.08      0.08        26
#            9       0.06      0.11      0.08        27
#
#     accuracy                           0.05       258
#    macro avg       0.06      0.05      0.05       258
# weighted avg       0.06      0.05      0.05       258
#
# mlp500_iden_Acc_wGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_window_4b0c19_1800.csv
# f1score :  0.5968992248062015
# accuracy score :  0.5968992248062015
# 0.9263565891472868
# At position 1 or 2 :  0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63        29
#            1       0.69      0.85      0.76        26
#            2       0.76      0.73      0.75        26
#            3       0.47      0.76      0.58        25
#            4       0.65      0.62      0.64        24
#            5       0.43      0.60      0.50        25
#            6       0.40      0.32      0.36        25
#            7       0.81      0.68      0.74        25
#            8       0.58      0.58      0.58        26
#            9       0.57      0.30      0.39        27
#
#     accuracy                           0.60       258
#    macro avg       0.61      0.60      0.59       258
# weighted avg       0.61      0.60      0.59       258
#
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c19_2400.csv
# f1score :  0.562015503875969
# accuracy score :  0.562015503875969
# 0.9069767441860465
# At position 1 or 2 :  0.8178294573643411
#               precision    recall  f1-score   support
#
#            0       0.65      0.45      0.53        29
#            1       0.76      0.96      0.85        26
#            2       0.71      0.65      0.68        26
#            3       0.53      0.72      0.61        25
#            4       0.65      0.54      0.59        24
#            5       0.41      0.56      0.47        25
#            6       0.24      0.16      0.19        25
#            7       0.63      0.68      0.65        25
#            8       0.42      0.38      0.40        26
#            9       0.56      0.52      0.54        27
#
#     accuracy                           0.56       258
#    macro avg       0.55      0.56      0.55       258
# weighted avg       0.56      0.56      0.55       258
#
# mlp500_idenhide_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.5677655677655677
# accuracy score :  0.5677655677655677
# 0.9230769230769231
# At position 1 or 2 :  0.8608058608058609
#               precision    recall  f1-score   support
#
#            0       0.64      0.47      0.54        30
#            1       0.72      0.85      0.78        27
#            2       0.81      0.48      0.60        27
#            3       0.53      0.67      0.59        27
#            4       0.60      0.56      0.58        27
#            5       0.36      0.63      0.46        27
#            6       0.43      0.33      0.38        27
#            7       0.71      0.81      0.76        27
#            8       0.43      0.33      0.38        27
#            9       0.62      0.56      0.59        27
#
#     accuracy                           0.57       273
#    macro avg       0.59      0.57      0.56       273
# weighted avg       0.59      0.57      0.56       273
#
# mlp500_idenhide_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.08914728682170543
# accuracy score :  0.08914728682170543
# 0.29457364341085274
# At position 1 or 2 :  0.1937984496124031
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.00      0.00      0.00        26
#            2       0.00      0.00      0.00        26
#            3       0.06      0.04      0.05        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.09      0.88      0.17        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.09       258
#    macro avg       0.02      0.09      0.02       258
# weighted avg       0.01      0.09      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# mlp500_idenhide_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.08914728682170543
# accuracy score :  0.08914728682170543
# 0.2248062015503876
# At position 1 or 2 :  0.13953488372093023
#               precision    recall  f1-score   support
#
#            0       0.06      0.10      0.08        29
#            1       0.07      0.04      0.05        26
#            2       0.00      0.00      0.00        26
#            3       0.08      0.08      0.08        25
#            4       0.00      0.00      0.00        24
#            5       0.29      0.16      0.21        25
#            6       0.00      0.00      0.00        25
#            7       0.12      0.16      0.14        25
#            8       0.15      0.27      0.19        26
#            9       0.08      0.07      0.08        27
#
#     accuracy                           0.09       258
#    macro avg       0.08      0.09      0.08       258
# weighted avg       0.08      0.09      0.08       258
#
# mlp500_idenhide_Acc_wGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_window_4b0c19_1800.csv
# f1score :  0.5968992248062015
# accuracy score :  0.5968992248062015
# 0.9263565891472868
# At position 1 or 2 :  0.8449612403100775
#               precision    recall  f1-score   support
#
#            0       0.73      0.55      0.63        29
#            1       0.70      0.88      0.78        26
#            2       0.70      0.73      0.72        26
#            3       0.58      0.84      0.69        25
#            4       0.69      0.46      0.55        24
#            5       0.37      0.68      0.48        25
#            6       0.48      0.40      0.43        25
#            7       0.76      0.76      0.76        25
#            8       0.53      0.35      0.42        26
#            9       0.60      0.33      0.43        27
#
#     accuracy                           0.60       258
#    macro avg       0.61      0.60      0.59       258
# weighted avg       0.62      0.60      0.59       258
#
# svc500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.37362637362637363
# accuracy score :  0.37362637362637363
# 0.7728937728937729
# At position 1 or 2 :  0.663003663003663
#               precision    recall  f1-score   support
#
#            0       0.28      0.90      0.43        30
#            1       0.94      0.63      0.76        27
#            2       0.60      0.22      0.32        27
#            3       0.45      0.19      0.26        27
#            4       0.62      0.59      0.60        27
#            5       0.24      0.15      0.18        27
#            6       0.20      0.11      0.14        27
#            7       0.46      0.44      0.45        27
#            8       0.12      0.04      0.06        27
#            9       0.24      0.41      0.30        27
#
#     accuracy                           0.37       273
#    macro avg       0.42      0.37      0.35       273
# weighted avg       0.41      0.37      0.35       273
#
# svc500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.313953488372093
# At position 1 or 2 :  0.20155038759689922
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.10      1.00      0.18        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.313953488372093
# At position 1 or 2 :  0.20155038759689922
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.10      1.00      0.18        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_wGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_window_4b0c19_1800.csv
# f1score :  0.40697674418604657
# accuracy score :  0.4069767441860465
# 0.751937984496124
# At position 1 or 2 :  0.6511627906976745
#               precision    recall  f1-score   support
#
#            0       0.42      0.76      0.54        29
#            1       0.94      0.65      0.77        26
#            2       0.86      0.23      0.36        26
#            3       0.50      0.32      0.39        25
#            4       0.57      0.67      0.62        24
#            5       0.40      0.08      0.13        25
#            6       0.00      0.00      0.00        25
#            7       0.38      0.48      0.42        25
#            8       0.00      0.00      0.00        26
#            9       0.22      0.81      0.35        27
#
#     accuracy                           0.41       258
#    macro avg       0.43      0.40      0.36       258
# weighted avg       0.43      0.41      0.36       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c19_2400.csv
# f1score :  0.3023255813953488
# accuracy score :  0.3023255813953488
# 0.748062015503876
# At position 1 or 2 :  0.6201550387596899
#               precision    recall  f1-score   support
#
#            0       0.26      0.79      0.40        29
#            1       0.90      0.73      0.81        26
#            2       0.40      0.31      0.35        26
#            3       0.00      0.00      0.00        25
#            4       0.69      0.38      0.49        24
#            5       0.16      0.76      0.27        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.30       258
#    macro avg       0.24      0.30      0.23       258
# weighted avg       0.24      0.30      0.23       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.0989010989010989
# accuracy score :  0.0989010989010989
# 0.3076923076923077
# At position 1 or 2 :  0.2087912087912088
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.10      1.00      0.18        27
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        27
#            4       0.00      0.00      0.00        27
#            5       0.00      0.00      0.00        27
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00        27
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       273
#    macro avg       0.01      0.10      0.02       273
# weighted avg       0.01      0.10      0.02       273
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.35271317829457366
# accuracy score :  0.35271317829457366
# 0.7248062015503876
# At position 1 or 2 :  0.5813953488372093
#               precision    recall  f1-score   support
#
#            0       0.25      0.86      0.39        29
#            1       0.95      0.77      0.85        26
#            2       0.80      0.15      0.26        26
#            3       0.54      0.28      0.37        25
#            4       0.64      0.67      0.65        24
#            5       0.12      0.04      0.06        25
#            6       0.25      0.04      0.07        25
#            7       0.62      0.20      0.30        25
#            8       0.00      0.00      0.00        26
#            9       0.16      0.44      0.24        27
#
#     accuracy                           0.35       258
#    macro avg       0.43      0.35      0.32       258
# weighted avg       0.43      0.35      0.32       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Acc_w_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.313953488372093
# At position 1 or 2 :  0.2131782945736434
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.10      1.00      0.18        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c19_1200.csv
# f1score :  0.0989010989010989
# accuracy score :  0.0989010989010989
# 0.3076923076923077
# At position 1 or 2 :  0.2087912087912088
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.10      1.00      0.18        27
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        27
#            4       0.00      0.00      0.00        27
#            5       0.00      0.00      0.00        27
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00        27
#            8       0.00      0.00      0.00        27
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       273
#    macro avg       0.01      0.10      0.02       273
# weighted avg       0.01      0.10      0.02       273
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_w_400_window_4b0c19_1200.csv
# f1score :  0.10077519379844961
# accuracy score :  0.10077519379844961
# 0.3062015503875969
# At position 1 or 2 :  0.2131782945736434
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        29
#            1       0.10      1.00      0.18        26
#            2       0.00      0.00      0.00        26
#            3       0.00      0.00      0.00        25
#            4       0.00      0.00      0.00        24
#            5       0.00      0.00      0.00        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.10       258
#    macro avg       0.01      0.10      0.02       258
# weighted avg       0.01      0.10      0.02       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# svc500_Gyro_400_window_4b0c17&4b0c18_1200.sav
# Gyro_400_window_4b0c19_1200.csv
# f1score :  0.31007751937984496
# accuracy score :  0.31007751937984496
# 0.8604651162790697
# At position 1 or 2 :  0.7170542635658915
#               precision    recall  f1-score   support
#
#            0       0.19      0.97      0.31        29
#            1       0.88      0.81      0.84        26
#            2       0.44      0.54      0.48        26
#            3       0.25      0.24      0.24        25
#            4       0.57      0.33      0.42        24
#            5       0.21      0.12      0.15        25
#            6       0.00      0.00      0.00        25
#            7       0.00      0.00      0.00        25
#            8       0.00      0.00      0.00        26
#            9       0.00      0.00      0.00        27
#
#     accuracy                           0.31       258
#    macro avg       0.25      0.30      0.25       258
# weighted avg       0.25      0.31      0.25       258
# C:\Users\nilu1\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# with pd.option_context("display.max_rows",None,"display.max_columns",None):
#     print(df)
