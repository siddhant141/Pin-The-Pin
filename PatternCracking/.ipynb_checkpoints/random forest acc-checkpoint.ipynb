# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from os import listdir
from os.path import isfile, join

# %%
path="C:\\Users\\nilu1\\PatternCracking\\acc\\"
pathex=[]
temp = [f for f in listdir(path) if isfile(join(path, f))]
temp.sort()
for i in range(len(temp)):
    st=temp[i]
    if(st[:2]=="27"):
        pathex.append(temp[i])
    if(st[:2]=="10"):
        pathex.append(temp[i])
# print(pathex)

# %%
# n -> number of lines in csv file
# actual -> the actual key pressed
# n=130
actual=1
x=[]
y=[]
z=[]
temp=pd.read_csv(path+pathex[0])
x=list(temp["X"])
y=list(temp["Y"])
z=list(temp["Z"])
maxx=max(x)
minx=min(x)
maxy=max(y)
miny=min(y)
maxz=max(z)
minz=min(z)
data=[[maxx-x[0],minx-x[0],maxy-y[0],miny-y[0],maxz-z[0],minz-z[0]]]
df=pd.DataFrame(data, columns = ['X','XX', 'Y','YY','Z','ZZ'])
ind=pathex[0].rfind("_")+3
df.insert(6, "key", str(pathex[0][ind]))
df
# Out:
#           X        XX         Y        YY         Z        ZZ key
# 0  1.154007 -2.197876  0.574615 -0.620087  2.147598 -4.261688   2

# %%
for i in range(1,len(pathex)):
#     print(pathex[i])
    dff=pd.read_csv(path+pathex[i])
    x=list(dff["X"])
    y=list(dff["Y"])
    z=list(dff["Z"])
    maxx=max(x)
    minx=min(x)
    maxy=max(y)
    miny=min(y)
    maxz=max(z)
    minz=min(z)
    print(pathex[i])
#     if(type(maxx)==str or type(maxy)==str or type(maxz)==str or type(minx)==str or type(miny)==str or type(minz)==str):
#         continue
#     if(type(x[0])==str or type(y[0])==str or type(z[0])==str):
#         continue
    data=[[maxx-x[0],minx-x[0],maxy-y[0],miny-y[0],maxz-z[0],minz-z[0]]]
    temp=pd.DataFrame(data, columns = ['X','XX', 'Y','YY','Z','ZZ'])
    ind=pathex[i].rfind("_")+3
    temp.insert(6, "key", str(pathex[i][ind]))
    df=df.append(temp,ignore_index = True)
df
# Out:
# 10-Jan-2020_10_12_27_AM21092.csv
# 10-Jan-2020_10_12_32_AM3845.csv
# 10-Jan-2020_10_13_11_AM41338.csv
# 10-Jan-2020_10_13_27_AM51123.csv
# 10-Jan-2020_10_13_33_AM61534.csv
# 10-Jan-2020_10_13_36_AM71095.csv
# 10-Jan-2020_10_13_40_AM81167.csv
# 10-Jan-2020_10_13_43_AM91066.csv
# 10-Jan-2020_10_13_47_AM01036.csv
# 10-Jan-2020_10_13_54_AM11009.csv
# 10-Jan-2020_10_13_59_AM21378.csv
# 10-Jan-2020_10_14_03_AM31212.csv
# 10-Jan-2020_10_14_09_AM4774.csv
# 10-Jan-2020_10_14_14_AM51063.csv
# 10-Jan-2020_10_14_18_AM61056.csv
# 10-Jan-2020_10_14_23_AM71075.csv
# 10-Jan-2020_10_14_30_AM81669.csv
# 10-Jan-2020_10_14_35_AM91486.csv
# 10-Jan-2020_10_14_40_AM01401.csv
# 10-Jan-2020_10_14_48_AM1984.csv
# 10-Jan-2020_10_14_53_AM21153.csv
# 10-Jan-2020_10_14_58_AM31318.csv
# 10-Jan-2020_10_15_29_AM41282.csv
# 27-Dec-2019_8_30_48_PM2.csv
# 27-Dec-2019_8_30_56_PM3.csv
# 27-Dec-2019_8_31_01_PM3.csv
# 27-Dec-2019_8_31_07_PM3.csv
# 27-Dec-2019_8_31_13_PM3.csv
# 27-Dec-2019_8_31_19_PM4.csv
# 27-Dec-2019_8_31_23_PM4.csv
# 27-Dec-2019_8_31_27_PM4.csv
# 27-Dec-2019_8_31_32_PM4.csv
# 27-Dec-2019_8_31_38_PM5.csv
# 27-Dec-2019_8_31_41_PM5.csv
# 27-Dec-2019_8_31_46_PM5.csv
# 27-Dec-2019_8_31_49_PM5.csv
# 27-Dec-2019_8_31_53_PM6.csv
# 27-Dec-2019_8_31_58_PM6.csv
# 27-Dec-2019_8_32_04_PM6.csv
# 27-Dec-2019_8_32_11_PM6.csv
# 27-Dec-2019_8_32_25_PM7.csv
# 27-Dec-2019_8_32_30_PM7.csv
# 27-Dec-2019_8_32_34_PM7.csv
# 27-Dec-2019_8_32_40_PM7.csv
# 27-Dec-2019_8_33_10_PM8.csv
# 27-Dec-2019_8_33_16_PM8.csv
# 27-Dec-2019_8_33_22_PM8.csv
# 27-Dec-2019_8_33_34_PM8.csv
# 27-Dec-2019_8_33_43_PM9.csv
# 27-Dec-2019_8_33_58_PM9.csv
# 27-Dec-2019_8_34_10_PM9.csv
# 27-Dec-2019_8_34_16_PM9.csv
# 27-Dec-2019_8_34_36_PM0.csv
# 27-Dec-2019_8_34_41_PM0.csv
# 27-Dec-2019_8_34_52_PM0.csv
# 27-Dec-2019_8_34_58_PM0.csv
#             X        XX         Y        YY         Z        ZZ key
# 0    1.154007 -2.197876  0.574615 -0.620087  2.147598 -4.261688   2
# 1    0.538696 -0.802063  0.110138 -0.304062  1.532288 -1.745376   2
# 2    0.481247 -3.090912  1.491592 -0.988800  1.187515 -3.332733   5
# 3    0.632080 -2.334335  1.017532 -0.248993  1.326386 -2.688690   8
# 4    1.048660 -1.596939  1.204285 -0.960068  2.286469 -1.635238   3
# ..        ...       ...       ...       ...       ...       ...  ..
# 175  2.698257  0.000000  0.694321 -2.212250  4.644760  0.000000   9
# 176  6.797150  0.000000  2.624054 -3.677490  7.644699 -2.116470   0
# 177  3.454834 -0.471649  0.000000 -3.040634  8.049301  0.000000   0
# 178  4.587280 -0.270554  0.000000 -4.747696  6.469132 -1.146820   0
# 179  4.065353 -0.126892  1.946487 -3.246536  4.975158 -2.178726   0
#
# [180 rows x 7 columns]

# %%
X = df.iloc[:, 0:6].values
y = df.iloc[:, 6].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
regressor = RandomForestRegressor(n_estimators=20, random_state=1)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#    Actual  Predicted
# 0       7       4.45
# 1       7       4.65
# 2       2       3.55
# 3       6       6.55
# 4       7       4.90
# 5       3       4.70
# 6       1       5.20
# 7       3       4.85
# 8       6       7.05
# 9       0       4.90
# 10      1       5.45
# 11      4       5.65
# 12      5       3.60
# 13      4       4.60
# 14      6       6.15
# 15      5       4.55
# 16      7       4.00
# 17      1       4.25

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.0972222222222223
# Mean Squared Error: 6.268750000000001
# Root Mean Squared Error: 2.5037471917108567
