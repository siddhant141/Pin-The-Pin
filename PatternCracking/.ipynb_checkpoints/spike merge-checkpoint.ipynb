# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
import concurrent.futures

# %%
foldertype="Acc_wGyro"
folder="Acc_w"
folderg="Gyro"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\"+folder+"\\"
pathg="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\"+folderg+"\\"
pathex=[]
pathexg=[]
temp = [f for f in listdir(path) if isfile(join(path, f))]
tempg = [f for f in listdir(pathg) if isfile(join(pathg, f))]
# temp.sort()
# files=["all"]
# files=["66b325","b56522","a99827"]
# files=["66b325","b56522"]
# files=["a99828","a99830"]
# files=["a99828","a99830","66b325","b56522"]
# files=["a29c12","a29c08","66b325","b56522"]
# files=["4b0c10"]
# files=["4b0c09"]
files=["4b0c19"]
for i in range(len(temp)):
    st=temp[i]
    if(os.path.getsize(path+st)<4096):
        continue
    if(temp[i][:6] in files):
        pathex.append(temp[i])
    st=tempg[i]
    if(os.path.getsize(pathg+st)<4096):
        continue
    if(tempg[i][:6] in files):
        pathexg.append(tempg[i])
#     if(files[0]=="all"):
#         pathex.append(temp[i])
# print(pathex)
print(len(temp))
print(len(tempg))
print(len(pathex))
print(len(pathexg))
# Out:
# 2924
# 4315
# 273
# 273

# %%
# folder_n_no.ofvalues_no.offiles_keycolno.
propath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Processed\\"
def savefile():
    df.to_csv (propath+foldertype+"_"+str(n)+"_"+fcode+"_"+"&".join(files)+"_"+str(keypos)+".csv", index = False, header=True)

# %%
def acc4v(i):
    try:
        dff=pd.read_csv(path+pathex[i])
        mini=10000
        minkeyd=1000
        keydt=pathex[i].rfind("_")+4
        for j in dff.index:
            t=abs(dff['Time'][j] - int(pathex[i][keydt:-4]))
            if(t < mini):
                mini=t
                minkeyd=j
        
        minkeyu=minkeyd+50
        window=minkeyu-minkeyd
        left=int(nn/2)-window    
        dff=dff.head(minkeyu + left)
        dff=dff.tail(nn)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")
        dff=dff.drop(columns="Time")      
        return dff
    except:
        print("error : ",pathex[i])
#         traceback.print_exc()

# %%
#taking into account that error might occur while reading a file (putting try and except)
# n -> number of lines in csv file
# actual -> the actual key pressed
# minkeyd -> index of nearest key down time
# minkeyu -> index of nearest key up time
# keydt -> key down time from file name
# keyut -> key up time from file name
fcode="window"
nn=200
n=200+nn
keypos=1
actual=1
df=pd.read_csv(pathg+pathex[0])
for i in range(len(pathex)):
    try:
        dff=pd.read_csv(pathg+pathex[i])
        mini=10000
        minkeyd=1000
        keydt=pathex[i].rfind("_")+4
        for j in dff.index:
            t=abs(dff['Time'][j] - int(pathex[i][keydt:-4]))
            if(t < mini):
                mini=t
                minkeyd=j
                
        minkeyu=minkeyd+50
        window=minkeyu-minkeyd
        left=int((n-nn)/2)-window    
        dff=dff.head(minkeyu + left)
        dff=dff.tail(n-nn)
        dff.reset_index(inplace=True)
        dff=dff.drop(columns="index")
        dff=dff.drop(columns="Time")
        
        df1=acc4v(i)
        dff=dff.append(df1,ignore_index=True)        
        
        df1=dff.stack().swaplevel()
        df1.index=df1.index.map('{0[0]}_{0[1]}'.format) 
        dff=df1.to_frame().T
        ind=pathex[i].rfind("_")+3
        print(i,pathex[i])
        dff.insert(n*3, "key", int(pathex[i][ind]))
        keypos=n*3
        if(i==0):
            df=dff
        else:
            df=df.append(dff,ignore_index = True)
    except:
        print("error : ",pathex[i])
#         traceback.print_exec()
        continue
# Out:
# 0 4b0c19-04-2020_03_49_01_PM0771.csv
# 1 4b0c19-04-2020_03_49_03_PM1562.csv
# 2 4b0c19-04-2020_03_49_04_PM2551.csv
# 3 4b0c19-04-2020_03_49_05_PM3416.csv
# error :  4b0c19-04-2020_03_49_05_PM3416.csv
# 4 4b0c19-04-2020_03_49_06_PM4366.csv
# error :  4b0c19-04-2020_03_49_06_PM4366.csv
# 5 4b0c19-04-2020_03_49_07_PM5760.csv
# 6 4b0c19-04-2020_03_49_08_PM6399.csv
# error :  4b0c19-04-2020_03_49_08_PM6399.csv
# 7 4b0c19-04-2020_03_49_09_PM7295.csv
# error :  4b0c19-04-2020_03_49_09_PM7295.csv
# 8 4b0c19-04-2020_03_49_10_PM8612.csv
# 9 4b0c19-04-2020_03_49_11_PM9758.csv
# 10 4b0c19-04-2020_03_49_12_PM0428.csv
# error :  4b0c19-04-2020_03_49_12_PM0428.csv
# 11 4b0c19-04-2020_03_49_14_PM2567.csv
# 12 4b0c19-04-2020_03_49_15_PM4653.csv
# 13 4b0c19-04-2020_03_49_16_PM6469.csv
# 14 4b0c19-04-2020_03_49_17_PM8535.csv
# 15 4b0c19-04-2020_03_49_19_PM0704.csv
# 16 4b0c19-04-2020_03_49_20_PM3808.csv
# 17 4b0c19-04-2020_03_49_22_PM5602.csv
# 18 4b0c19-04-2020_03_49_23_PM7441.csv
# 19 4b0c19-04-2020_03_49_24_PM9319.csv
# error :  4b0c19-04-2020_03_49_24_PM9319.csv
# 20 4b0c19-04-2020_03_49_25_PM1728.csv
# 21 4b0c19-04-2020_03_49_27_PM3723.csv
# 22 4b0c19-04-2020_03_49_28_PM6567.csv
# 23 4b0c19-04-2020_03_49_29_PM9504.csv
# 24 4b0c19-04-2020_03_49_31_PM2905.csv
# 25 4b0c19-04-2020_03_49_32_PM5575.csv
# 26 4b0c19-04-2020_03_49_33_PM81053.csv
# 27 4b0c19-04-2020_03_49_35_PM1646.csv
# 28 4b0c19-04-2020_03_49_36_PM4689.csv
# 29 4b0c19-04-2020_03_49_38_PM7493.csv
# 30 4b0c19-04-2020_03_49_39_PM0792.csv
# 31 4b0c19-04-2020_03_49_40_PM4617.csv
# 32 4b0c19-04-2020_03_49_42_PM8516.csv
# 33 4b0c19-04-2020_03_49_43_PM2668.csv
# 34 4b0c19-04-2020_03_49_45_PM6628.csv
# 35 4b0c19-04-2020_03_49_46_PM0601.csv
# 36 4b0c19-04-2020_03_49_47_PM5631.csv
# 37 4b0c19-04-2020_03_49_49_PM9575.csv
# 38 4b0c19-04-2020_03_49_50_PM3637.csv
# 39 4b0c19-04-2020_03_49_51_PM7650.csv
# 40 4b0c19-04-2020_03_49_53_PM1655.csv
# 41 4b0c19-04-2020_03_49_54_PM5534.csv
# 42 4b0c19-04-2020_03_49_55_PM0514.csv
# 43 4b0c19-04-2020_03_49_57_PM6709.csv
# 44 4b0c19-04-2020_03_49_58_PM1596.csv
# 45 4b0c19-04-2020_03_49_59_PM6407.csv
# error :  4b0c19-04-2020_03_49_59_PM6407.csv
# 46 4b0c19-04-2020_03_50_01_PM2709.csv
# 47 4b0c19-04-2020_03_50_02_PM7713.csv
# 48 4b0c19-04-2020_03_50_04_PM2585.csv
# 49 4b0c19-04-2020_03_50_05_PM8785.csv
# 50 4b0c19-04-2020_03_50_07_PM3627.csv
# 51 4b0c19-04-2020_03_50_08_PM8829.csv
# 52 4b0c19-04-2020_03_50_09_PM4596.csv
# 53 4b0c19-04-2020_03_50_11_PM9471.csv
# 54 4b0c19-04-2020_03_50_12_PM4622.csv
# 55 4b0c19-04-2020_03_50_13_PM0541.csv
# 56 4b0c19-04-2020_03_50_15_PM7646.csv
# 57 4b0c19-04-2020_03_50_16_PM3677.csv
# 58 4b0c19-04-2020_03_50_17_PM9465.csv
# 59 4b0c19-04-2020_03_50_19_PM5634.csv
# 60 4b0c19-04-2020_03_50_20_PM1762.csv
# 61 4b0c19-04-2020_03_50_22_PM7551.csv
# 62 4b0c19-04-2020_03_50_23_PM4729.csv
# 63 4b0c19-04-2020_03_50_24_PM1670.csv
# 64 4b0c19-04-2020_03_50_26_PM8463.csv
# 65 4b0c19-04-2020_03_50_27_PM5557.csv
# 66 4b0c19-04-2020_03_50_28_PM2654.csv
# 67 4b0c19-04-2020_03_50_30_PM9502.csv
# 68 4b0c19-04-2020_03_50_31_PM6595.csv
# 69 4b0c19-04-2020_03_50_33_PM3782.csv
# 70 4b0c19-04-2020_03_50_34_PM0552.csv
# 71 4b0c19-04-2020_03_50_36_PM8830.csv
# 72 4b0c19-04-2020_03_50_37_PM6707.csv
# 73 4b0c19-04-2020_03_50_39_PM4752.csv
# 74 4b0c19-04-2020_03_50_40_PM2510.csv
# 75 4b0c19-04-2020_03_50_41_PM0562.csv
# 76 4b0c19-04-2020_03_50_43_PM9660.csv
# 77 4b0c19-04-2020_03_50_44_PM7673.csv
# 78 4b0c19-04-2020_03_50_46_PM5839.csv
# 79 4b0c19-04-2020_03_50_47_PM3646.csv
# 80 4b0c19-04-2020_03_50_49_PM1747.csv
# 81 4b0c19-04-2020_03_50_50_PM9381.csv
# error :  4b0c19-04-2020_03_50_50_PM9381.csv
# 82 4b0c19-04-2020_03_50_51_PM8711.csv
# 83 4b0c19-04-2020_03_50_53_PM7704.csv
# 84 4b0c19-04-2020_03_50_54_PM6408.csv
# error :  4b0c19-04-2020_03_50_54_PM6408.csv
# 85 4b0c19-04-2020_03_50_56_PM5683.csv
# 86 4b0c19-04-2020_03_50_57_PM4630.csv
# 87 4b0c19-04-2020_03_50_58_PM3637.csv
# 88 4b0c19-04-2020_03_51_00_PM2525.csv
# 89 4b0c19-04-2020_03_51_01_PM1807.csv
# 90 4b0c19-04-2020_03_51_02_PM0211.csv
# error :  4b0c19-04-2020_03_51_02_PM0211.csv
# 91 4b0c19-04-2020_03_51_21_PM0140.csv
# error :  4b0c19-04-2020_03_51_21_PM0140.csv
# 92 4b0c19-04-2020_03_51_22_PM1472.csv
# 93 4b0c19-04-2020_03_51_23_PM2476.csv
# 94 4b0c19-04-2020_03_51_24_PM3343.csv
# error :  4b0c19-04-2020_03_51_24_PM3343.csv
# 95 4b0c19-04-2020_03_51_25_PM4302.csv
# error :  4b0c19-04-2020_03_51_25_PM4302.csv
# 96 4b0c19-04-2020_03_51_26_PM5214.csv
# error :  4b0c19-04-2020_03_51_26_PM5214.csv
# 97 4b0c19-04-2020_03_51_27_PM6392.csv
# error :  4b0c19-04-2020_03_51_27_PM6392.csv
# 98 4b0c19-04-2020_03_51_28_PM7266.csv
# error :  4b0c19-04-2020_03_51_28_PM7266.csv
# 99 4b0c19-04-2020_03_51_29_PM8311.csv
# error :  4b0c19-04-2020_03_51_29_PM8311.csv
# 100 4b0c19-04-2020_03_51_31_PM9172.csv
# error :  4b0c19-04-2020_03_51_31_PM9172.csv
# 101 4b0c19-04-2020_03_51_32_PM0554.csv
# 102 4b0c19-04-2020_03_51_33_PM2697.csv
# 103 4b0c19-04-2020_03_51_35_PM4433.csv
# 104 4b0c19-04-2020_03_51_36_PM6272.csv
# error :  4b0c19-04-2020_03_51_36_PM6272.csv
# 105 4b0c19-04-2020_03_51_37_PM8892.csv
# 106 4b0c19-04-2020_03_51_38_PM0141.csv
# error :  4b0c19-04-2020_03_51_38_PM0141.csv
# 107 4b0c19-04-2020_03_51_40_PM3608.csv
# 108 4b0c19-04-2020_03_51_41_PM5447.csv
# 109 4b0c19-04-2020_03_51_42_PM7471.csv
# 110 4b0c19-04-2020_03_51_43_PM9301.csv
# error :  4b0c19-04-2020_03_51_43_PM9301.csv
# 111 4b0c19-04-2020_03_51_45_PM1677.csv
# 112 4b0c19-04-2020_03_51_46_PM3317.csv
# error :  4b0c19-04-2020_03_51_46_PM3317.csv
# 113 4b0c19-04-2020_03_51_48_PM6584.csv
# 114 4b0c19-04-2020_03_51_49_PM9685.csv
# 115 4b0c19-04-2020_03_51_50_PM2672.csv
# 116 4b0c19-04-2020_03_51_52_PM5590.csv
# 117 4b0c19-04-2020_03_51_53_PM8489.csv
# 118 4b0c19-04-2020_03_51_54_PM1641.csv
# 119 4b0c19-04-2020_03_51_56_PM4458.csv
# 120 4b0c19-04-2020_03_51_57_PM7648.csv
# 121 4b0c19-04-2020_03_51_58_PM0643.csv
# 122 4b0c19-04-2020_03_52_00_PM4625.csv
# 123 4b0c19-04-2020_03_52_01_PM8634.csv
# 124 4b0c19-04-2020_03_52_02_PM2640.csv
# 125 4b0c19-04-2020_03_52_04_PM6602.csv
# 126 4b0c19-04-2020_03_52_05_PM0657.csv
# 127 4b0c19-04-2020_03_52_06_PM5660.csv
# 128 4b0c19-04-2020_03_52_08_PM9525.csv
# 129 4b0c19-04-2020_03_52_09_PM3700.csv
# 130 4b0c19-04-2020_03_52_11_PM7645.csv
# 131 4b0c19-04-2020_03_52_12_PM1567.csv
# 132 4b0c19-04-2020_03_52_13_PM5696.csv
# 133 4b0c19-04-2020_03_52_15_PM0466.csv
# 134 4b0c19-04-2020_03_52_16_PM6706.csv
# 135 4b0c19-04-2020_03_52_17_PM1496.csv
# 136 4b0c19-04-2020_03_52_19_PM6441.csv
# 137 4b0c19-04-2020_03_52_20_PM2619.csv
# 138 4b0c19-04-2020_03_52_21_PM7403.csv
# error :  4b0c19-04-2020_03_52_21_PM7403.csv
# 139 4b0c19-04-2020_03_52_23_PM2592.csv
# 140 4b0c19-04-2020_03_52_24_PM8435.csv
# 141 4b0c19-04-2020_03_52_25_PM3622.csv
# 142 4b0c19-04-2020_03_52_27_PM8612.csv
# 143 4b0c19-04-2020_03_52_28_PM4579.csv
# 144 4b0c19-04-2020_03_52_29_PM9679.csv
# 145 4b0c19-04-2020_03_52_31_PM4633.csv
# 146 4b0c19-04-2020_03_52_32_PM0480.csv
# 147 4b0c19-04-2020_03_52_33_PM7590.csv
# 148 4b0c19-04-2020_03_52_35_PM3687.csv
# 149 4b0c19-04-2020_03_52_36_PM9687.csv
# 150 4b0c19-04-2020_03_52_37_PM5537.csv
# 151 4b0c19-04-2020_03_52_39_PM11028.csv
# 152 4b0c19-04-2020_03_52_41_PM7538.csv
# 153 4b0c19-04-2020_03_52_42_PM4769.csv
# 154 4b0c19-04-2020_03_52_44_PM1658.csv
# 155 4b0c19-04-2020_03_52_45_PM8461.csv
# 156 4b0c19-04-2020_03_52_46_PM51069.csv
# 157 4b0c19-04-2020_03_52_48_PM2939.csv
# 158 4b0c19-04-2020_03_52_50_PM9751.csv
# 159 4b0c19-04-2020_03_52_51_PM61089.csv
# 160 4b0c19-04-2020_03_52_53_PM3589.csv
# 161 4b0c19-04-2020_03_52_54_PM0573.csv
# 162 4b0c19-04-2020_03_52_55_PM8677.csv
# 163 4b0c19-04-2020_03_52_57_PM6700.csv
# 164 4b0c19-04-2020_03_52_58_PM4551.csv
# 165 4b0c19-04-2020_03_52_59_PM2559.csv
# 166 4b0c19-04-2020_03_53_01_PM0540.csv
# 167 4b0c19-04-2020_03_53_02_PM9654.csv
# 168 4b0c19-04-2020_03_53_03_PM7616.csv
# 169 4b0c19-04-2020_03_53_05_PM5746.csv
# 170 4b0c19-04-2020_03_53_06_PM3374.csv
# error :  4b0c19-04-2020_03_53_06_PM3374.csv
# 171 4b0c19-04-2020_03_53_08_PM1641.csv
# 172 4b0c19-04-2020_03_53_09_PM9603.csv
# 173 4b0c19-04-2020_03_53_10_PM8861.csv
# 174 4b0c19-04-2020_03_53_12_PM7610.csv
# 175 4b0c19-04-2020_03_53_13_PM6755.csv
# 176 4b0c19-04-2020_03_53_15_PM5661.csv
# 177 4b0c19-04-2020_03_53_16_PM4576.csv
# 178 4b0c19-04-2020_03_53_17_PM3516.csv
# 179 4b0c19-04-2020_03_53_18_PM2610.csv
# 180 4b0c19-04-2020_03_53_20_PM1393.csv
# error :  4b0c19-04-2020_03_53_20_PM1393.csv
# 181 4b0c19-04-2020_03_53_21_PM0256.csv
# error :  4b0c19-04-2020_03_53_21_PM0256.csv
# 182 4b0c19-04-2020_03_53_32_PM0765.csv
# 183 4b0c19-04-2020_03_53_33_PM1332.csv
# error :  4b0c19-04-2020_03_53_33_PM1332.csv
# 184 4b0c19-04-2020_03_53_34_PM2396.csv
# error :  4b0c19-04-2020_03_53_34_PM2396.csv
# 185 4b0c19-04-2020_03_53_36_PM3506.csv
# 186 4b0c19-04-2020_03_53_37_PM4421.csv
# error :  4b0c19-04-2020_03_53_37_PM4421.csv
# 187 4b0c19-04-2020_03_53_38_PM5552.csv
# 188 4b0c19-04-2020_03_53_39_PM6481.csv
# 189 4b0c19-04-2020_03_53_40_PM7574.csv
# 190 4b0c19-04-2020_03_53_42_PM8598.csv
# 191 4b0c19-04-2020_03_53_43_PM9828.csv
# 192 4b0c19-04-2020_03_53_44_PM0610.csv
# 193 4b0c19-04-2020_03_53_45_PM2580.csv
# 194 4b0c19-04-2020_03_53_47_PM4690.csv
# 195 4b0c19-04-2020_03_53_48_PM6613.csv
# 196 4b0c19-04-2020_03_53_49_PM8657.csv
# 197 4b0c19-04-2020_03_53_51_PM0617.csv
# 198 4b0c19-04-2020_03_53_52_PM3561.csv
# 199 4b0c19-04-2020_03_53_53_PM5758.csv
# 200 4b0c19-04-2020_03_53_55_PM7640.csv
# 201 4b0c19-04-2020_03_53_56_PM9744.csv
# 202 4b0c19-04-2020_03_53_58_PM11396.csv
# 203 4b0c19-04-2020_03_54_00_PM3790.csv
# 204 4b0c19-04-2020_03_54_01_PM6628.csv
# 205 4b0c19-04-2020_03_54_02_PM9625.csv
# 206 4b0c19-04-2020_03_54_04_PM2727.csv
# 207 4b0c19-04-2020_03_54_05_PM5580.csv
# 208 4b0c19-04-2020_03_54_06_PM8660.csv
# 209 4b0c19-04-2020_03_54_08_PM1615.csv
# 210 4b0c19-04-2020_03_54_09_PM4598.csv
# 211 4b0c19-04-2020_03_54_10_PM7576.csv
# 212 4b0c19-04-2020_03_54_12_PM0622.csv
# 213 4b0c19-04-2020_03_54_13_PM4561.csv
# 214 4b0c19-04-2020_03_54_14_PM8623.csv
# 215 4b0c19-04-2020_03_54_16_PM2568.csv
# 216 4b0c19-04-2020_03_54_17_PM6635.csv
# 217 4b0c19-04-2020_03_54_18_PM0459.csv
# 218 4b0c19-04-2020_03_54_20_PM5641.csv
# 219 4b0c19-04-2020_03_54_21_PM9641.csv
# 220 4b0c19-04-2020_03_54_22_PM3658.csv
# 221 4b0c19-04-2020_03_54_24_PM7671.csv
# 222 4b0c19-04-2020_03_54_25_PM1621.csv
# 223 4b0c19-04-2020_03_54_26_PM5560.csv
# 224 4b0c19-04-2020_03_54_27_PM0450.csv
# 225 4b0c19-04-2020_03_54_29_PM6420.csv
# error :  4b0c19-04-2020_03_54_29_PM6420.csv
# 226 4b0c19-04-2020_03_54_30_PM1559.csv
# 227 4b0c19-04-2020_03_54_31_PM6435.csv
# 228 4b0c19-04-2020_03_54_33_PM2585.csv
# 229 4b0c19-04-2020_03_54_34_PM7556.csv
# 230 4b0c19-04-2020_03_54_35_PM2676.csv
# 231 4b0c19-04-2020_03_54_36_PM8496.csv
# 232 4b0c19-04-2020_03_54_38_PM31015.csv
# 233 4b0c19-04-2020_03_54_39_PM8573.csv
# 234 4b0c19-04-2020_03_54_40_PM4627.csv
# 235 4b0c19-04-2020_03_54_42_PM9464.csv
# 236 4b0c19-04-2020_03_54_43_PM4588.csv
# 237 4b0c19-04-2020_03_54_44_PM0347.csv
# error :  4b0c19-04-2020_03_54_44_PM0347.csv
# 238 4b0c19-04-2020_03_54_46_PM7650.csv
# 239 4b0c19-04-2020_03_54_47_PM3554.csv
# 240 4b0c19-04-2020_03_54_48_PM9384.csv
# error :  4b0c19-04-2020_03_54_48_PM9384.csv
# 241 4b0c19-04-2020_03_54_49_PM5619.csv
# 242 4b0c19-04-2020_03_54_51_PM1498.csv
# 243 4b0c19-04-2020_03_54_52_PM7604.csv
# 244 4b0c19-04-2020_03_54_53_PM4563.csv
# 245 4b0c19-04-2020_03_54_54_PM1456.csv
# 246 4b0c19-04-2020_03_54_56_PM8486.csv
# 247 4b0c19-04-2020_03_54_57_PM5668.csv
# 248 4b0c19-04-2020_03_54_58_PM2413.csv
# error :  4b0c19-04-2020_03_54_58_PM2413.csv
# 249 4b0c19-04-2020_03_55_00_PM9600.csv
# 250 4b0c19-04-2020_03_55_01_PM6634.csv
# 251 4b0c19-04-2020_03_55_02_PM3575.csv
# 252 4b0c19-04-2020_03_55_04_PM0561.csv
# 253 4b0c19-04-2020_03_55_05_PM8240.csv
# error :  4b0c19-04-2020_03_55_05_PM8240.csv
# 254 4b0c19-04-2020_03_55_06_PM6626.csv
# 255 4b0c19-04-2020_03_55_08_PM4642.csv
# 256 4b0c19-04-2020_03_55_09_PM2545.csv
# 257 4b0c19-04-2020_03_55_10_PM0473.csv
# 258 4b0c19-04-2020_03_55_11_PM9607.csv
# 259 4b0c19-04-2020_03_55_13_PM7576.csv
# 260 4b0c19-04-2020_03_55_14_PM5816.csv
# 261 4b0c19-04-2020_03_55_15_PM3523.csv
# 262 4b0c19-04-2020_03_55_17_PM1617.csv
# 263 4b0c19-04-2020_03_55_18_PM9481.csv
# 264 4b0c19-04-2020_03_55_19_PM8856.csv
# 265 4b0c19-04-2020_03_55_21_PM7682.csv
# 266 4b0c19-04-2020_03_55_22_PM6748.csv
# 267 4b0c19-04-2020_03_55_23_PM5672.csv
# 268 4b0c19-04-2020_03_55_25_PM4536.csv
# 269 4b0c19-04-2020_03_55_26_PM3167.csv
# error :  4b0c19-04-2020_03_55_26_PM3167.csv
# 270 4b0c19-04-2020_03_55_27_PM2516.csv
# 271 4b0c19-04-2020_03_55_28_PM1463.csv
# 272 4b0c19-04-2020_03_55_29_PM0335.csv
# error :  4b0c19-04-2020_03_55_29_PM0335.csv

# %%
savefile()
