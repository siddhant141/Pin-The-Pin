# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score
import pickle

# %%
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    X = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
    
    #Create KNN Classifier
    logmodel = KNeighborsClassifier(n_neighbors=3)
    logmodel.fit(X_train, y_train)
#     y_pred = knn.predict(X_train)
#     print(file,end=" : ")
#     print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    
    p = logmodel.predict_proba(X_test)
    nn = 3
    top_n = np.argsort(p)[:,:-nn-1:-1]
#     for i in range(len(y_test)):
#         print(y_test[i],top_n[i])
    count=0
    count1=0
    count2=0
    count3=0
    count12=0
    for i in range(len(y_pred)):
        if(y_test[i] in top_n[i]):
            count+=1
        if(y_test[i] in top_n[i][:2]):
            count12+=1
        if(y_test[i] == top_n[i][0]):
            count1+=1
        elif(y_test[i] == top_n[i][1]):
            count2+=1
        elif(y_test[i] == top_n[i][2]):
            count3+=1
#         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(file)
    print(l,count)
    print("Any one : ",count/l)
    print("At position 1 and 2 : ",count12/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
#     score.append([count/l,file])
#     score12.append([count12/l,file])
    
#     df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     print(df)
    score.append([accuracy_score(y_test, y_pred),file,count12/l])
#     score.append(accuracy_score(y_test, y_pred))
# score12.sort(reverse=True)
# score.sort(reverse=True)
print("------------------------------------------Test : ---------------------------------------------")
for i in range(len(score)):
#     print(score[i][1]+" : "+str(score[i][0]))
    print(score[i][1])
for i in range(len(score)):
    print(score[i][0])
print("-----------------------------------------Test : --------------------------------------------")
for i in range(len(score)):
    print(score[i][2])

# for i in range(len(score)):
#     print(score12[i][1]+" : "+str(score12[i][0]))
#     df
# Out:
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 682 414
# Any one :  0.6070381231671554
# At position 1 and 2 :  0.46187683284457476
# At position 1 :  0.2829912023460411
# At position 2 :  0.17888563049853373
# At position 3 :  0.14516129032258066
# Acc_wGyro_400_wininituni_4b0c17&4b0c18_1200.csv
# 683 383
# Any one :  0.5607613469985359
# At position 1 and 2 :  0.4128843338213763
# At position 1 :  0.26500732064421667
# At position 2 :  0.1478770131771596
# At position 3 :  0.1478770131771596
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 683 392
# Any one :  0.5739385065885798
# At position 1 and 2 :  0.4289897510980966
# At position 1 :  0.22986822840409957
# At position 2 :  0.19912152269399708
# At position 3 :  0.14494875549048317
# Acc_wGyro_400_winuni_4b0c17&4b0c18_1200.csv
# 683 403
# Any one :  0.5900439238653001
# At position 1 and 2 :  0.4260614934114202
# At position 1 :  0.26207906295754024
# At position 2 :  0.16398243045387995
# At position 3 :  0.16398243045387995
# Acc_wGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 683 373
# Any one :  0.5461200585651538
# At position 1 and 2 :  0.40995607613469986
# At position 1 :  0.26500732064421667
# At position 2 :  0.14494875549048317
# At position 3 :  0.13616398243045388
# Acc_wGyro_600_window_4b0c17&4b0c18_1800.csv
# 590 341
# Any one :  0.5779661016949152
# At position 1 and 2 :  0.4033898305084746
# At position 1 :  0.2576271186440678
# At position 2 :  0.14576271186440679
# At position 3 :  0.17457627118644067
# Acc_wGyro_600_wininituni_4b0c17&4b0c18_1800.csv
# At position 2 :  0.18887262079062958
# At position 3 :  0.11420204978038068
# Gyro_200_wininituniend_4b0c17&4b0c18_600.csv
# 683 399
# Any one :  0.5841874084919473
# At position 1 and 2 :  0.4685212298682284
# At position 1 :  0.2840409956076135
# At position 2 :  0.18448023426061494
# At position 3 :  0.11566617862371889
# Gyro_200_winuni_4b0c17&4b0c18_600.csv
# 683 462
# Any one :  0.6764275256222547
# At position 1 and 2 :  0.5373352855051244
# At position 1 :  0.35431918008784774
# At position 2 :  0.18301610541727673
# At position 3 :  0.1390922401171303
# Gyro_200_winuniend_4b0c17&4b0c18_600.csv
# 683 464
# Any one :  0.6793557833089312
# At position 1 and 2 :  0.5666178623718887
# At position 1 :  0.34699853587115664
# At position 2 :  0.21961932650073207
# At position 3 :  0.11273792093704246
# Gyro_400_window_4b0c17&4b0c18_1200.csv
# 590 407
# Any one :  0.6898305084745763
# At position 1 and 2 :  0.576271186440678
# At position 1 :  0.3576271186440678
# At position 2 :  0.21864406779661016
# At position 3 :  0.1135593220338983
# Gyro_400_wininituni_4b0c17&4b0c18_1200.csv
# 678 461
# Any one :  0.6799410029498525
# At position 1 and 2 :  0.5457227138643068
# At position 1 :  0.3407079646017699
# At position 2 :  0.20501474926253688
# At position 3 :  0.13421828908554573
# Gyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 655 415
# Any one :  0.6335877862595419
# At position 1 and 2 :  0.5129770992366413
# At position 1 :  0.3297709923664122
# At position 2 :  0.183206106870229
# At position 3 :  0.12061068702290076
# Gyro_400_winuni_4b0c17&4b0c18_1200.csv
# 678 480
# Any one :  0.7079646017699115
# At position 1 and 2 :  0.6017699115044248
# At position 1 :  0.41002949852507375
# At position 2 :  0.19174041297935104
# At position 3 :  0.10619469026548672
# Gyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 655 445
# Any one :  0.6793893129770993
# At position 1 and 2 :  0.5694656488549619
# At position 1 :  0.36793893129770994
# At position 2 :  0.2015267175572519
# At position 3 :  0.1099236641221374
# ------------------------------------------Test : ---------------------------------------------
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# Acc_wGyro_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_wGyro_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_wGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# Acc_wGyro_600_window_4b0c17&4b0c18_1800.csv
# Acc_wGyro_600_wininituni_4b0c17&4b0c18_1800.csv
# Acc_wGyro_600_wininituniend_4b0c17&4b0c18_1800.csv
# Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.csv
# Acc_wGyro_600_winuniend_4b0c17&4b0c18_1800.csv
# Acc_wGyro_800_window_4b0c17&4b0c18_2400.csv
# Acc_wGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# Acc_wGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.csv
# Acc_wGyro_800_winuniend_4b0c17&4b0c18_2400.csv
# Acc_w_200_window_4b0c17&4b0c18_600.csv
# Acc_w_200_wininituni_4b0c17&4b0c18_600.csv
# Acc_w_200_wininituniend_4b0c17&4b0c18_600.csv
# Acc_w_200_winuni_4b0c17&4b0c18_600.csv
# Acc_w_200_winuniend_4b0c17&4b0c18_600.csv
# Acc_w_400_window_4b0c17&4b0c18_1200.csv
# Acc_w_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_w_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_w_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_w_400_winuniend_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_window_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# Acc_woGyro_600_window_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_wininituni_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_wininituniend_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_winuniend_4b0c17&4b0c18_1800.csv
# Acc_woGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_winuniend_4b0c17&4b0c18_2400.csv
# Acc_wo_200_window_4b0c17&4b0c18_600.csv
# Acc_wo_200_wininituni_4b0c17&4b0c18_600.csv
# Acc_wo_200_wininituniend_4b0c17&4b0c18_600.csv
# Acc_wo_200_winuni_4b0c17&4b0c18_600.csv
# Acc_wo_200_winuniend_4b0c17&4b0c18_600.csv
# Acc_wo_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_wo_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_wo_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_wo_400_winuniend_4b0c17&4b0c18_1200.csv
# Gyro_200_window_4b0c17&4b0c18_600.csv
# Gyro_200_wininituni_4b0c17&4b0c18_600.csv
# Gyro_200_wininituniend_4b0c17&4b0c18_600.csv
# Gyro_200_winuni_4b0c17&4b0c18_600.csv
# Gyro_200_winuniend_4b0c17&4b0c18_600.csv
# Gyro_400_window_4b0c17&4b0c18_1200.csv
# Gyro_400_wininituni_4b0c17&4b0c18_1200.csv
# Gyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# Gyro_400_winuni_4b0c17&4b0c18_1200.csv
# Gyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 0.31671554252199413
# 0.3001464128843338
# 0.2679355783308931
# 0.32503660322108346
# 0.3089311859443631
# 0.3423728813559322
# 0.2949852507374631
# 0.3190839694656489
# 0.3466076696165192
# 0.3114503816793893
# 0.27288135593220336
# 0.29056047197640117
# 0.2870229007633588
# 0.3281004709576138
# 0.2900763358778626
# 0.24743777452415813
# 0.25329428989751096
# 0.24743777452415813
# 0.25329428989751096
# 0.27379209370424595
# 0.2983050847457627
# 0.28276877761413843
# 0.2580152671755725
# 0.28424153166421207
# 0.2564885496183206
# 0.41116751269035534
# 0.3513909224011713
# 0.3367496339677892
# 0.37481698389458273
# 0.3367496339677892
# 0.37181663837011886
# 0.3584070796460177
# 0.3603053435114504
# 0.4247787610619469
# 0.36793893129770994
# 0.36430678466076694
# 0.300763358778626
# 0.34513274336283184
# 0.33893129770992364
# 0.30456852791878175
# 0.2796486090775988
# 0.2108345534407028
# 0.3411420204978038
# 0.3279648609077599
# 0.29455081001472755
# 0.2778625954198473
# 0.33578792341678937
# 0.30229007633587784
# 0.41642228739002934
# 0.35724743777452417
# 0.2884333821376281
# 0.3923865300146413
# 0.363103953147877
# 0.3847457627118644
# 0.3775811209439528
# 0.34961832061068704
# 0.415929203539823
# 0.3938931297709924
# 0.46187683284457476
# 0.4128843338213763
# 0.4289897510980966
# 0.4260614934114202
# 0.40995607613469986
# 0.4033898305084746
# 0.44837758112094395
# 0.4549618320610687
# 0.4498525073746313
# 0.4305343511450382
# 0.4
# 0.4144542772861357
# 0.42748091603053434
# 0.41130298273155413
# 0.42442748091603055
# 0.38945827232796487
# 0.4289897510980966
# 0.3718887262079063
# 0.40263543191800877
# 0.42020497803806733
# 0.42033898305084744
# 0.4212076583210604
# 0.41068702290076337
# 0.4256259204712813
# 0.4183206106870229
# 0.5346869712351946
# 0.5124450951683748
# 0.493411420204978
# 0.5490483162518301
# 0.5183016105417276
# 0.5585738539898133
# 0.5294985250737463
# 0.5129770992366413
# 0.5501474926253688
# 0.5145038167938931
# 0.5265486725663717
# 0.45038167938931295
# 0.5176991150442478
# 0.4870229007633588
# 0.45685279187817257
# 0.47291361639824303
# 0.4011713030746706
# 0.486090775988287
# 0.49194729136163984
# 0.4050073637702504
# 0.43206106870229005
# 0.49189985272459497
# 0.46412213740458014
# 0.5953079178885631
# 0.5212298682284041
# 0.4685212298682284
# 0.5373352855051244
# 0.5666178623718887
# 0.576271186440678
# 0.5457227138643068
# 0.5129770992366413
# 0.6017699115044248
# 0.5694656488549619
# -----------------------------------------Test : --------------------------------------------

# %%
# # save trained model
# for file in pathex:
#     ni=file.rfind("_")+1
#     n=int(file[ni:].split(".")[0])
#     df=pd.read_csv(path+file)
#     X = df.iloc[:, 0:n].values
#     y = df.iloc[:, n].values
#     X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#     #Create KNN Classifier
#     logmodel = KNeighborsClassifier(n_neighbors=7)
#     logmodel.fit(X_train, y_train)
#     filename = "knn_"+file[:-4]+".sav"
#     pickle.dump(logmodel, open(modelpath+filename, 'wb'))
