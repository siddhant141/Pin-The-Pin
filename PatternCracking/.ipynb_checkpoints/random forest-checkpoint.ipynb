# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from os import listdir
from os.path import isfile, join

# %%
path="C:\\Users\\nilu1\\PatternCracking\\gyro\\"
pathex=[]
temp = [f for f in listdir(path) if isfile(join(path, f))]
temp.sort()
for i in range(len(temp)):
    st=temp[i]
    if(st[:2]=="27"):
        pathex.append(temp[i])
    if(st[:2]=="10"):
        pathex.append(temp[i])
#     if(st[:2]=="09"):
#         pathex.append(temp[i])
# print(pathex)

# %%
# n -> number of lines in csv file
# actual -> the actual key pressed
n=100
# n=40
actual=1
df=pd.read_csv(path+pathex[0])
df=df.head(n)
df1=df.stack().swaplevel()
df1.index=df1.index.map('{0[0]}_{0[1]}'.format)
df=df1.to_frame().T
ind=pathex[0].rfind("_")+3
df.insert(n*4, "key", str(pathex[0][ind]))
df
# Out:
#    Time_0       X_0       Y_0       Z_0  Time_1       X_1       Y_1       Z_1  \
# 0   264.0  0.022934 -0.029602 -0.047653   279.0  0.141174 -0.148926 -0.193588
#
#    Time_2       X_2  ...     Z_97  Time_98      X_98      Y_98      Z_98  \
# 0   289.0  0.003754  ... -0.04126   2105.0 -0.036728  0.680923 -0.064697
#
#    Time_99      X_99      Y_99      Z_99  key
# 0   2125.0 -0.117691  0.730988 -0.109436    2
#
# [1 rows x 401 columns]

# %%
for i in range(1,len(pathex)):
    dff=pd.read_csv(path+pathex[i])
    dff=dff.head(n)
    df1=dff.stack().swaplevel()
    df1.index=df1.index.map('{0[0]}_{0[1]}'.format) 
    dff=df1.to_frame().T
    ind=pathex[i].rfind("_")+3
    dff.insert(n*4, "key", str(pathex[i][ind]))
    df=df.append(dff,ignore_index = True)
df
# Out:
#     Time_0        X_0        Y_0        Z_0 Time_1        X_1          Y_1  \
# 0      264   0.022934 -0.0296021 -0.0476532    279   0.141174    -0.148926
# 1        4   0.120926  0.0140686  -0.045517     18  0.0825806    0.0140686
# 2        7  0.0314484   0.150421    0.10788     21  0.0112152     0.163208
# 3       21    0.21254   0.022583 -0.0476532     41  0.0655365 -0.000839233
# 4       13   0.135849 -0.0455933 -0.0135651     19    0.13797   -0.0605011
# ..     ...        ...        ...        ...    ...        ...          ...
# 175     20  -0.163437  -0.813232  -0.108063     43   -0.29126     -1.15092
# 176     10  -0.356247  -0.823883   0.123108     27  -0.624695     -1.20525
# 177     11  -0.230545  -0.730148  0.0336151     24  -0.545868    -0.941071
# 178     14  -0.476624  -0.547989  -0.116577     31  -0.729095    -0.974091
# 179     25  -0.153854   -0.67688  -0.168777     30  -0.263565     -1.02097
#
#             Z_1 Time_2         X_2  ...       Z_97 Time_98       X_98  \
# 0     -0.193588    289  0.00375366  ... -0.0412598    2105 -0.0367279
# 1    -0.0135651     31   0.0271912  ...  0.0141296    1712 -0.0441895
# 2     0.0844421     26  -0.0122223  ... -0.0753479    1668 -0.0654907
# 3    -0.0124969     59  -0.0186157  ...  -0.120087    1760  -0.110229
# 4   -0.00717163     41   0.0985565  ...  0.0397034    1779   0.026123
# ..          ...    ...         ...  ...        ...     ...        ...
# 175   -0.126175     53   -0.162369  ...   0.203003    1550   0.640839
# 176    0.168915     47     -0.8452  ...  -0.119781    1648   0.249893
# 177   0.0730286     42   -0.781296  ...   -0.21991    1607   0.148682
# 178   -0.191147     44   -0.835617  ...   0.726044    1568  -0.644928
# 179   -0.169846     40   -0.252914  ...  0.0666351    1649  0.0592041
#
#           Y_98       Z_98 Time_99       X_99       Y_99       Z_99 key
# 0     0.680923 -0.0646973    2125  -0.117691   0.730988  -0.109436   2
# 1   -0.0850067  0.0162659    1731  -0.020752  -0.106308  0.0141296   2
# 2     0.259079 -0.0646973    1679 -0.0090332  0.0236511    0.06633   5
# 3    -0.403519 -0.0881348    1776  -0.124084  -0.413101 -0.0519104   8
# 4   -0.0605011  0.0386353    1784  0.0239868 -0.0359955  0.0375671   3
# ..         ...        ...     ...        ...        ...        ...  ..
# 175  0.0975647   0.260513    1573   0.660019   0.180664   0.249863   9
# 176  -0.163422 -0.0931397    1658    0.40329  -0.429733  0.0591888   0
# 177   0.336182  -0.226303    1625   0.132706   0.340454   -0.23056   0
# 178   0.589722   0.779297    1577  -0.601257   0.651505   0.530029   0
# 179  -0.043045  0.0666351    1675  0.0645294 -0.0302582  0.0549316   0
#
# [180 rows x 401 columns]

# %%
X = df.iloc[:, 0:n*4].values
y = df.iloc[:, n*4].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
regressor = RandomForestRegressor(n_estimators=20, random_state=1)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#    Actual  Predicted
# 0       7       4.65
# 1       7       3.85
# 2       2       1.75
# 3       6       3.90
# 4       7       6.70
# 5       3       3.15
# 6       1       4.20
# 7       3       3.70
# 8       6       5.00
# 9       0       5.45
# 10      1       5.20
# 11      4       5.00
# 12      5       4.55
# 13      4       4.90
# 14      6       6.35
# 15      5       5.00
# 16      7       4.70
# 17      1       4.50
# 18      5       6.05
# 19      8       5.05
# 20      2       4.40
# 21      6       4.25
# 22      3       3.90
# 23      3       5.95
# 24      0       4.50
# 25      7       4.85
# 26      4       4.90
# 27      7       5.30
# 28      8       4.10
# 29      4       2.65
# 30      8       3.60
# 31      4       3.95
# 32      1       6.30
# 33      2       5.20
# 34      7       4.05
# 35      6       4.15

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.0999999999999996
# Mean Squared Error: 6.7316666666666665
# Root Mean Squared Error: 2.5945455607228536
