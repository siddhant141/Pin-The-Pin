# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier # NN. very much useful and hidden layers. 0.31
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Report files\\"
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    x = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
#     sc = StandardScaler()
#     X_train = sc.fit_transform(X_train)
#     X_test = sc.transform(X_test)
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic",hidden_layer_sizes=(800,10))
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic")
    logmodel = MLPClassifier(solver="lbfgs",max_iter=1500,warm_start=True,activation="logistic")
    logmodel.fit(X_train, y_train)
#     y_pred = logmodel.predict(X_train)
#     print(file,end=" : ")
#     print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    
    p = logmodel.predict_proba(X_test)
    nn = 3
    top_n = np.argsort(p)[:,:-nn-1:-1]
#     for i in range(len(y_test)):
#         print(y_test[i],top_n[i])
    count=0
    count1=0
    count2=0
    count3=0
    count12=0
    for i in range(len(y_pred)):
        if(y_test[i] in top_n[i]):
            count+=1
        if(y_test[i] in top_n[i][:2]):
            count12+=1
        if(y_test[i] == top_n[i][0]):
            count1+=1
        elif(y_test[i] == top_n[i][1]):
            count2+=1
        elif(y_test[i] == top_n[i][2]):
            count3+=1
#         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(file)
    print(l,count)
    print("Any one : ",count/l)
    print("At position 1 and 2 : ",count12/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
    score.append([accuracy_score(y_test, y_pred),file,count12/l])
    
print("----------------------------------------------Test : --------------------------------------")
for i in range(len(score)):
#     print(score[i][1]+" : "+str(score[i][0]))
    print(score[i][1])
for i in range(len(score)):
    print(score[i][0])
print("----------------------------------------------2nd guess : --------------------------------------")
for i in range(len(score)):
    print(score[i][0])
# print("------------------------------------------Test : ----------------------------------------")
# for i in range(len(score)):
#     print(score12[i][1]+" : "+str(score12[i][0]))
# df
# Out:
# Acc_woGyro_400_window_4b0c17&4b0c18_1200.csv
# 591 542
# Any one :  0.9170896785109983
# At position 1 and 2 :  0.8307952622673435
# At position 1 :  0.6243654822335025
# At position 2 :  0.20642978003384094
# At position 3 :  0.08629441624365482
# Acc_woGyro_400_wininituni_4b0c17&4b0c18_1200.csv
# 683 539
# Any one :  0.7891654465592972
# At position 1 and 2 :  0.6544655929721815
# At position 1 :  0.41874084919472915
# At position 2 :  0.23572474377745242
# At position 3 :  0.13469985358711567
# Acc_woGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 683 461
# Any one :  0.6749633967789166
# At position 1 and 2 :  0.5446559297218155
# At position 1 :  0.35431918008784774
# At position 2 :  0.1903367496339678
# At position 3 :  0.13030746705710103
# Acc_woGyro_400_winuni_4b0c17&4b0c18_1200.csv
# 683 627
# Any one :  0.91800878477306
# At position 1 and 2 :  0.828696925329429
# At position 1 :  0.5900439238653001
# At position 2 :  0.23865300146412885
# At position 3 :  0.08931185944363104
# Acc_woGyro_400_winuniend_4b0c17&4b0c18_1200.csv
#
# Gyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 655 439
# Any one :  0.6702290076335878
# At position 1 and 2 :  0.5282442748091603
# At position 1 :  0.33435114503816793
# At position 2 :  0.19389312977099238
# At position 3 :  0.14198473282442747
# Gyro_400_winuni_4b0c17&4b0c18_1200.csv
# 678 605
# Any one :  0.8923303834808259
# At position 1 and 2 :  0.7713864306784661
# At position 1 :  0.5294985250737463
# At position 2 :  0.24188790560471976
# At position 3 :  0.12094395280235988
# Gyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 655 523
# Any one :  0.7984732824427481
# At position 1 and 2 :  0.6625954198473283
# At position 1 :  0.44580152671755724
# At position 2 :  0.216793893129771
# At position 3 :  0.13587786259541984
# ----------------------------------------------Test : --------------------------------------
# Acc_woGyro_400_window_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_woGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# Acc_woGyro_600_window_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_wininituni_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_wininituniend_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.csv
# Acc_woGyro_600_winuniend_4b0c17&4b0c18_1800.csv
# Acc_woGyro_800_wininituni_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_wininituniend_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.csv
# Acc_woGyro_800_winuniend_4b0c17&4b0c18_2400.csv
# Acc_wo_200_window_4b0c17&4b0c18_600.csv
# Acc_wo_200_wininituni_4b0c17&4b0c18_600.csv
# Acc_wo_200_wininituniend_4b0c17&4b0c18_600.csv
# Acc_wo_200_winuni_4b0c17&4b0c18_600.csv
# Acc_wo_200_winuniend_4b0c17&4b0c18_600.csv
# Acc_wo_400_wininituni_4b0c17&4b0c18_1200.csv
# Acc_wo_400_wininituniend_4b0c17&4b0c18_1200.csv
# Acc_wo_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_wo_400_winuniend_4b0c17&4b0c18_1200.csv
# Gyro_200_window_4b0c17&4b0c18_600.csv
# Gyro_200_wininituni_4b0c17&4b0c18_600.csv
# Gyro_200_wininituniend_4b0c17&4b0c18_600.csv
# Gyro_200_winuni_4b0c17&4b0c18_600.csv
# Gyro_200_winuniend_4b0c17&4b0c18_600.csv
# Gyro_400_window_4b0c17&4b0c18_1200.csv
# Gyro_400_wininituni_4b0c17&4b0c18_1200.csv
# Gyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# Gyro_400_winuni_4b0c17&4b0c18_1200.csv
# Gyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 0.6243654822335025
# 0.41874084919472915
# 0.35431918008784774
# 0.5900439238653001
# 0.4494875549048316
# 0.631578947368421
# 0.42920353982300885
# 0.39083969465648855
# 0.6047197640117994
# 0.5145038167938931
# 0.4351032448377581
# 0.3938931297709924
# 0.588495575221239
# 0.49312977099236643
# 0.5008460236886633
# 0.3601756954612006
# 0.2913616398243045
# 0.465592972181552
# 0.3967789165446559
# 0.3240058910162003
# 0.3236641221374046
# 0.4374079528718704
# 0.3984732824427481
# 0.593841642228739
# 0.3733528550512445
# 0.3103953147877013
# 0.493411420204978
# 0.43191800878477304
# 0.5813559322033899
# 0.40117994100294985
# 0.33435114503816793
# 0.5294985250737463
# 0.44580152671755724
