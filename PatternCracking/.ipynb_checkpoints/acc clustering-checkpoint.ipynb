# %%
path='C:\\Users\\nilu1\\PatternCracking\\acc\\9_Dec_2019_10_11_34.csv'
f=open(path)
para=f.readlines()
line=""
data=[]
for i in range(len(para)):
    line=para[i]
    line=line.split(",")
    for i in range(len(line)):
        line[i]=line[i].rstrip('\n')
        line[i]=line[i].strip('"')
        line[i]=float(line[i])
    line.pop(0)
    data.append(line)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.cluster import KMeans

X=np.array(data)
print(X)
# Out:
# [[-0.05357361  0.06214905  0.01783752]
#  [-0.11642456  0.0461731  -0.0151825 ]
#  [-0.21231079  0.1058197   0.01783752]
#  ...
#  [ 0.12112427 -0.01667786 -0.01838684]
#  [ 0.03269959  0.03764343 -0.01092529]
#  [ 0.01779175  0.04403687 -0.01306152]]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2], c='r', marker='o')

# %%
kmeans = KMeans(n_clusters=10)
kmeans.fit(X)
#print(kmeans.cluster_centers_)
print(kmeans.labels_)
fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2], c=kmeans.labels_, cmap='rainbow')
# Out:
# [1 1 6 ... 1 1 1]
