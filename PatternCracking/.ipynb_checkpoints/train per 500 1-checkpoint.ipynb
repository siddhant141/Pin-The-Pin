# %%
import pandas as pd
import numpy as np
import os
from math import ceil
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score
import pickle

# %%
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
iters=500
file=pathex[0]
ni=file.rfind("_")+1
n=int(file[ni:].split(".")[0])
dfuni=pd.read_csv(path+file)
last=ceil(dfuni.index[-1]/iters)
print(n)
print(last)

fpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Results\\"
f = open(fpath+file+"iden0"+".txt", "w")
f.write("\n",n)
f.write("\n",last)

X = dfuni.iloc[:, 0:n].values
y = dfuni.iloc[:, n].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.075)

# logmodel=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity",hidden_layer_sizes=(800,10))
logmodel=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity")

for i in range(last):

    if(i!=last-1):
#         df=dfuni.head(iters*(i+1))
        X = X_train[:iters*(i+1)]
        y = y_train[:iters*(i+1)]
    else:
        X=X_train
        y=y_train
        
    print(X_train.size,X.size)
    f.write("\n"+str(X_train.size)+str(X.size))
    
#     logmodel.fit(X_train, y_train)
    logmodel.fit(X, y)
    y_pred = logmodel.predict(X_test)

    p = logmodel.predict_proba(X_test)
    nn = 3
    top_n = np.argsort(p)[:,:-nn-1:-1]
    #     for i in range(len(y_test)):
    #         print(y_test[i],top_n[i])
    count=0
    count1=0
    count2=0
    count3=0
    count12=0
    for i in range(len(y_pred)):
        if(y_test[i] in top_n[i]):
            count+=1
        if(y_test[i] in top_n[i][:2]):
            count12+=1
        if(y_test[i] == top_n[i][0]):
            count1+=1
        elif(y_test[i] == top_n[i][1]):
            count2+=1
        elif(y_test[i] == top_n[i][2]):
            count3+=1
    #         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(file)
    print(l,count)
    print("Any one : ",count/l)
    print("At position 1 and 2 : ",count12/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
    print(accuracy_score(y_test, y_pred))
    
    f.write("\n",file)
    f.write("\n"+str(l)+str(count))
    f.write("\nAny one : ",count/l)
    f.write("\nAt position 1 and 2 : ",count12/l)
    f.write("\nAt position 1 : ",count1/l)
    f.write("\nAt position 2 : ",count2/l)
    f.write("\nAt position 3 : ",count3/l)
    f.write("\n",accuracy_score(y_test, y_pred))
    
f.close()
    
# filename = "zmlp500_"+file[:-4]+".sav"
# pickle.dump(logmodel, open(modelpath+filename, 'wb'))
# Out:
# 2400
# 5
# 5157600 1200000
# Acc_wGyro_800_wininituni_a29c12&a29c08&66b325&b56522_2400.csv
# 175 142
# Any one :  0.8114285714285714
# At position 1 and 2 :  0.68
# At position 1 :  0.4228571428571429
# At position 2 :  0.2571428571428571
# At position 3 :  0.13142857142857142
# 0.4228571428571429
# 5157600 2400000
# Acc_wGyro_800_wininituni_a29c12&a29c08&66b325&b56522_2400.csv
# 175 149
# Any one :  0.8514285714285714
# At position 1 and 2 :  0.7657142857142857
# At position 1 :  0.45714285714285713
# At position 2 :  0.30857142857142855
# At position 3 :  0.08571428571428572
# 0.45714285714285713
# 5157600 3600000
# Acc_wGyro_800_wininituni_a29c12&a29c08&66b325&b56522_2400.csv
# 175 148
# Any one :  0.8457142857142858
# At position 1 and 2 :  0.7257142857142858
# At position 1 :  0.5085714285714286
# At position 2 :  0.21714285714285714
# At position 3 :  0.12
# 0.5085714285714286
# 5157600 4800000
# Acc_wGyro_800_wininituni_a29c12&a29c08&66b325&b56522_2400.csv
# 175 147
# Any one :  0.84
# At position 1 and 2 :  0.72
# At position 1 :  0.4857142857142857
# At position 2 :  0.2342857142857143
# At position 3 :  0.12
# 0.4857142857142857
# 5157600 5157600
# Acc_wGyro_800_wininituni_a29c12&a29c08&66b325&b56522_2400.csv
# 175 153
# Any one :  0.8742857142857143
# At position 1 and 2 :  0.7542857142857143
# At position 1 :  0.52
# At position 2 :  0.2342857142857143
# At position 3 :  0.12
# 0.52
