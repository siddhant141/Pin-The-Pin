# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import Ridge
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn import datasets 
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Processed\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
# for i in range(len(pathex)):
#     print(pathex[i])

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    X = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
#     sc = StandardScaler()
#     X_train = sc.fit_transform(X_train)
#     X_test = sc.transform(X_test)
    ridge = Ridge()
    ridge.fit(X_train,y_train)
    y_prob = ridge.predict(X_train)
    y_pred = np.asarray([np.argmax(line) for line in y_prob])
    print(file,end=" : ")
    print(accuracy_score(y_train,y_pred))
    yp_test = ridge.predict(X_test)
    y_pred = np.asarray([np.argmax(line) for line in yp_test])
    df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
    score.append([accuracy_score(y_test, y_pred),file])
score.sort(reverse=True)
print("Test : ")
for i in range(len(score)):
    print(score[i][1]+" : "+str(score[i][0]))
#     df
# Out:
# Acc_w_25_4vuni_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Acc_w_25_4vuni_66b325_9.csv : 0.1
# Acc_w_25_4vuni_a99828_9.csv : 0.08125
# Acc_w_25_4vuni_all_9.csv : 0.10399562123700054
# Acc_w_25_4v_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Acc_w_25_4v_66b325&b56522_9.csv : 0.09598214285714286
# Acc_w_25_4v_66b325_9.csv : 0.1
# Acc_w_25_4v_a99828_9.csv : 0.08125
# Acc_w_25_4v_all_9.csv : 0.10139764318991505
# Acc_w_25_windowdelinit_66b325_75.csv : 0.1
# Acc_w_25_windowdelinit_all_75.csv : 0.10202407002188184
# Acc_w_25_window_66b325&b56522&a99827_75.csv : 0.09868421052631579
# Acc_w_25_window_66b325&b56522_75.csv : 0.09598214285714286
# Acc_w_25_window_66b325_75.csv : 0.1
# Acc_w_25_window_a99828_75.csv : 0.08125
# Acc_w_25_window_all_75.csv : 0.10202407002188184
# Acc_w_30_4vuni_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Acc_w_30_4vuni_66b325_9.csv : 0.1
# Acc_w_30_4vuni_a99828_9.csv : 0.08125
# Acc_w_30_4vuni_all_9.csv : 0.10399562123700054
# Acc_w_30_4v_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Acc_w_30_4v_66b325&b56522_9.csv : 0.09598214285714286
# Acc_w_30_4v_66b325_9.csv : 0.1
# Acc_w_30_4v_a99828_9.csv : 0.08125
# Acc_w_30_4v_all_9.csv : 0.10139764318991505
# Acc_w_30_windowdelinit_66b325_90.csv : 0.1
# Acc_w_30_windowdelinit_all_90.csv : 0.10202407002188184
# Acc_w_30_window_66b325&b56522&a99827_90.csv : 0.09868421052631579
# Acc_w_30_window_66b325&b56522_90.csv : 0.09598214285714286
# Acc_w_30_window_66b325_90.csv : 0.1
# Acc_w_30_window_a99828_90.csv : 0.08125
# Acc_w_30_window_all_90.csv : 0.10202407002188184
# Grav_25_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Grav_25_4v_66b325&b56522_9.csv : 0.09598214285714286
# Grav_25_window_66b325&b56522_75.csv : 0.09598214285714286
# Grav_30_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Grav_30_4v_66b325&b56522_9.csv : 0.09598214285714286
# Grav_30_window_66b325&b56522_90.csv : 0.09598214285714286
# Gyro_25_4vuni_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Gyro_25_4vuni_a99828_9.csv : 0.08125
# Gyro_25_4v_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Gyro_25_4v_66b325&b56522_9.csv : 0.09598214285714286
# Gyro_25_4v_a99828_9.csv : 0.08125
# Gyro_25_window_66b325&b56522&a99827_75.csv : 0.09868421052631579
# Gyro_25_window_66b325&b56522_75.csv : 0.09598214285714286
# Gyro_25_window_a99828_75.csv : 0.08125
# Gyro_30_4vuni_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.09598214285714286
# Gyro_30_4vuni_a99828_9.csv : 0.08125
# Gyro_30_4v_66b325&b56522&a99827_9.csv : 0.09868421052631579
# Gyro_30_4v_66b325&b56522_9.csv : 0.09598214285714286
# Gyro_30_4v_a99828_9.csv : 0.08125
# Gyro_30_window_66b325&b56522&a99827_90.csv : 0.09868421052631579
# Gyro_30_window_66b325&b56522_90.csv : 0.09598214285714286
# Gyro_30_window_a99828_90.csv : 0.08125
# Test :
# Gyro_30_window_a99828_90.csv : 0.175
# Gyro_30_4vuni_a99828_9.csv : 0.175
# Gyro_30_4v_a99828_9.csv : 0.175
# Gyro_25_window_a99828_75.csv : 0.175
# Gyro_25_4vuni_a99828_9.csv : 0.175
# Gyro_25_4v_a99828_9.csv : 0.175
# Acc_w_30_window_a99828_90.csv : 0.175
# Acc_w_30_4vuni_a99828_9.csv : 0.175
# Acc_w_30_4v_a99828_9.csv : 0.175
# Acc_w_25_window_a99828_75.csv : 0.175
# Acc_w_25_4vuni_a99828_9.csv : 0.175
# Acc_w_25_4v_a99828_9.csv : 0.175
# Gyro_30_window_66b325&b56522_90.csv : 0.11504424778761062
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Gyro_30_4v_66b325&b56522_9.csv : 0.11504424778761062
# Gyro_25_window_66b325&b56522_75.csv : 0.11504424778761062
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Gyro_25_4v_66b325&b56522_9.csv : 0.11504424778761062
# Grav_30_window_66b325&b56522_90.csv : 0.11504424778761062
# Grav_30_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Grav_30_4v_66b325&b56522_9.csv : 0.11504424778761062
# Grav_25_window_66b325&b56522_75.csv : 0.11504424778761062
# Grav_25_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Grav_25_4v_66b325&b56522_9.csv : 0.11504424778761062
# Acc_w_30_window_66b325&b56522_90.csv : 0.11504424778761062
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Acc_w_30_4v_66b325&b56522_9.csv : 0.11504424778761062
# Acc_w_25_window_66b325&b56522_75.csv : 0.11504424778761062
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.11504424778761062
# Acc_w_25_4v_66b325&b56522_9.csv : 0.11504424778761062
# Gyro_30_window_66b325&b56522&a99827_90.csv : 0.10457516339869281
# Gyro_30_4vuni_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Gyro_30_4v_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Gyro_25_window_66b325&b56522&a99827_75.csv : 0.10457516339869281
# Gyro_25_4vuni_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Gyro_25_4v_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Acc_w_30_window_66b325&b56522&a99827_90.csv : 0.10457516339869281
# Acc_w_30_4vuni_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Acc_w_30_4v_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Acc_w_25_window_66b325&b56522&a99827_75.csv : 0.10457516339869281
# Acc_w_25_4vuni_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Acc_w_25_4v_66b325&b56522&a99827_9.csv : 0.10457516339869281
# Acc_w_30_windowdelinit_66b325_90.csv : 0.09876543209876543
# Acc_w_30_window_66b325_90.csv : 0.09876543209876543
# Acc_w_30_4vuni_66b325_9.csv : 0.09876543209876543
# Acc_w_30_4v_66b325_9.csv : 0.09876543209876543
# Acc_w_25_windowdelinit_66b325_75.csv : 0.09876543209876543
# Acc_w_25_window_66b325_75.csv : 0.09876543209876543
# Acc_w_25_4vuni_66b325_9.csv : 0.09876543209876543
# Acc_w_25_4v_66b325_9.csv : 0.09876543209876543
# Acc_w_30_4v_all_9.csv : 0.09748083242059145
# Acc_w_25_4v_all_9.csv : 0.09748083242059145
# Acc_w_30_windowdelinit_all_90.csv : 0.09398907103825137
# Acc_w_30_window_all_90.csv : 0.09398907103825137
# Acc_w_25_windowdelinit_all_75.csv : 0.09398907103825137
# Acc_w_25_window_all_75.csv : 0.09398907103825137
# Acc_w_30_4vuni_all_9.csv : 0.08643326039387308
# Acc_w_25_4vuni_all_9.csv : 0.08643326039387308
