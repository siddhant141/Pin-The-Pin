# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn import datasets 
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import f1_score

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Standardized\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
# for i in range(len(pathex)):
#     print(pathex[i])

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    X = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
#     sc = StandardScaler()
#     X_train = sc.fit_transform(X_train)
#     X_test = sc.transform(X_test)
    gnb = GaussianNB().fit(X_train, y_train)
    y_pred = gnb.predict(X_train)
    print(file,end=" : ")
    print(accuracy_score(y_train,y_pred))
    y_pred = gnb.predict(X_test)
    df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
#     score.append([f1_score(y_test, y_pred, average="micro"),file])
    score.append([accuracy_score(y_test, y_pred),file])
score.sort(reverse=True)
print("-----------------------------Test : --------------------------")
for i in range(len(score)):
    print(score[i][1]+" : "+str(score[i][0]))
#     df
# Out:
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.2924107142857143
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.17838541666666666
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.171875
# Acc_w_25_4v_66b325&b56522_9.csv : 0.29910714285714285
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.17317708333333334
# Acc_w_25_4v_a99828&a99830_9.csv : 0.215625
# Acc_w_25_window_66b325&b56522_75.csv : 0.3080357142857143
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.1640625
# Acc_w_25_window_a99828&a99830_75.csv : 0.30625
# Acc_w_30_4vuni_66b325&b56522_9.csv : Acc_w_25_4vuni_66b325&b56522_9.csv : 0.2924107142857143
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.17838541666666666
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.171875
# Acc_w_25_4v_66b325&b56522_9.csv : 0.29910714285714285
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.17317708333333334
# Acc_w_25_4v_a99828&a99830_9.csv : 0.215625
# Acc_w_25_window_66b325&b56522_75.csv : 0.3080357142857143
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.1640625
# Acc_w_25_window_a99828&a99830_75.csv : 0.30625
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.3169642857142857
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.17057291666666666
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.2
# Acc_w_30_4v_66b325&b56522_9.csv : 0.30357142857142855
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.17057291666666666
# Acc_w_30_4v_a99828&a99830_9.csv : 0.228125
# Acc_w_30_window_66b325&b56522_90.csv : 0.29464285714285715
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.171875
# Acc_w_30_window_a99828&a99830_90.csv0.3169642857142857
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.17057291666666666
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.2
# Acc_w_30_4v_66b325&b56522_9.csv : 0.30357142857142855
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.17057291666666666
# Acc_w_30_4v_a99828&a99830_9.csv : 0.228125
# Acc_w_30_window_66b325&b56522_90.csv : 0.29464285714285715
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.171875
# Acc_w_30_window_a99828&a99830_90.csv : 0.303125
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.41294642857142855
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.24609375
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.353125
# Gyro_25_4v_66b325&b56522_9.csv : 0.3861607142857143
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.23307291666666666
# Gyro_25_4v_a99828&a99830_9.csv : 0.365625
# Gyro_25_window_66b325&b56522_75.csv : 0.35267857142857145
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.2526041666666667
#  : 0.303125
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.41294642857142855
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.24609375
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.353125
# Gyro_25_4v_66b325&b56522_9.csv : 0.3861607142857143
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.23307291666666666
# Gyro_25_4v_a99828&a99830_9.csv : 0.365625
# Gyro_25_window_66b325&b56522_75.csv : 0.35267857142857145
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.2526041666666667
# Gyro_25_window_a99828&a99830_75.csv : 0.378125
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.4107142857142857
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.2552083333333333
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.35625
# Gyro_30_4v_66b325&b56522_9.csv : 0.39285714285714285
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.24869791666666666
# Gyro_30_4v_a99828&a99830_9.csv : 0.365625
# Gyro_30_window_66b325&b56522_90.csv : 0.37276785714285715
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.24348958333333334
# Gyro_30_window_a99828&a99830_90.csvGyro_25_window_a99828&a99830_75.csv : 0.378125
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.4107142857142857
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.2552083333333333
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.35625
# Gyro_30_4v_66b325&b56522_9.csv : 0.39285714285714285
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.24869791666666666
# Gyro_30_4v_a99828&a99830_9.csv : 0.365625
# Gyro_30_window_66b325&b56522_90.csv : 0.37276785714285715
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.24348958333333334
# Gyro_30_window_a99828&a99830_90.csv : 0.390625
# -----------------------------Test : --------------------------
# Gyro_30_window_66b325&b56522_90.csv : 0.336283185840708
# Gyro_30_4v_66b325&b56522_9.csv : 0.336283185840708
# Gyro_25_4v_66b325&b56522_9.csv : 0.336283185840708
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.3274336283185841
# Gyro_25_window_66b325&b56522_75.csv : 0.3185840707964602
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.3008849557522124
# Acc_w_30_window_66b325&b56522_90.csv : 0.26548672566371684
# Acc_w_30_4v_66b325&b56522_9.csv : 0.26548672566371684
# Acc_w_25_4v_66b325&b56522_9.csv : 0.26548672566371684
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.24778761061946902
# Acc_w_25_window_66b325&b56522_75.csv : 0.24778761061946902
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.24778761061946902
# Gyro_30_4v_a99828&a99830_9.csv : 0.2375
# Gyro_25_4v_a99828&a99830_9.csv : 0.2375
# Acc_w_25_window_a99828&a99830_75.csv : 0.225
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.22279792746113988
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.21761658031088082
# Gyro_25_window_a99828&a99830_75.csv : 0.2125
# Acc_w_30_window_a99828&a99830_90.csv : 0.2125
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.21243523316062177
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.21243523316062177
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.20725388601036268
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.20207253886010362
# Gyro_30_window_a99828&a99830_90.csv : 0.1875
# Acc_w_25_4v_a99828&a99830_9.csv : 0.1875
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.1625
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.15
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.12435233160621761
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.12435233160621761
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.12435233160621761
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.11917098445595854
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.1125
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.10362694300518134
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.10362694300518134
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.1
# Acc_w_30_4v_a99828&a99830_9.csv : 0.1
#  : 0.390625
# -----------------------------Test : --------------------------
# Gyro_30_window_66b325&b56522_90.csv : 0.336283185840708
# Gyro_30_4v_66b325&b56522_9.csv : 0.336283185840708
# Gyro_25_4v_66b325&b56522_9.csv : 0.336283185840708
# Gyro_30_4vuni_66b325&b56522_9.csv : 0.3274336283185841
# Gyro_25_window_66b325&b56522_75.csv : 0.3185840707964602
# Gyro_25_4vuni_66b325&b56522_9.csv : 0.3008849557522124
# Acc_w_30_window_66b325&b56522_90.csv : 0.26548672566371684
# Acc_w_30_4v_66b325&b56522_9.csv : 0.26548672566371684
# Acc_w_25_4v_66b325&b56522_9.csv : 0.26548672566371684
# Acc_w_30_4vuni_66b325&b56522_9.csv : 0.24778761061946902
# Acc_w_25_window_66b325&b56522_75.csv : 0.24778761061946902
# Acc_w_25_4vuni_66b325&b56522_9.csv : 0.24778761061946902
# Gyro_30_4v_a99828&a99830_9.csv : 0.2375
# Gyro_25_4v_a99828&a99830_9.csv : 0.2375
# Acc_w_25_window_a99828&a99830_75.csv : 0.225
# Gyro_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.22279792746113988
# Gyro_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.21761658031088082
# Gyro_25_window_a99828&a99830_75.csv : 0.2125
# Acc_w_30_window_a99828&a99830_90.csv : 0.2125
# Gyro_30_window_a99828&a99830&66b325&b56522_90.csv : 0.21243523316062177
# Gyro_25_window_a99828&a99830&66b325&b56522_75.csv : 0.21243523316062177
# Gyro_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.20725388601036268
# Gyro_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.20207253886010362
# Gyro_30_window_a99828&a99830_90.csv : 0.1875
# Acc_w_25_4v_a99828&a99830_9.csv : 0.1875
# Gyro_30_4vuni_a99828&a99830_9.csv : 0.1625
# Gyro_25_4vuni_a99828&a99830_9.csv : 0.15
# Acc_w_30_window_a99828&a99830&66b325&b56522_90.csv : 0.12435233160621761
# Acc_w_25_window_a99828&a99830&66b325&b56522_75.csv : 0.12435233160621761
# Acc_w_25_4v_a99828&a99830&66b325&b56522_9.csv : 0.12435233160621761
# Acc_w_30_4v_a99828&a99830&66b325&b56522_9.csv : 0.11917098445595854
# Acc_w_25_4vuni_a99828&a99830_9.csv : 0.1125
# Acc_w_30_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.10362694300518134
# Acc_w_25_4vuni_a99828&a99830&66b325&b56522_9.csv : 0.10362694300518134
# Acc_w_30_4vuni_a99828&a99830_9.csv : 0.1
# Acc_w_30_4v_a99828&a99830_9.csv : 0.1

# %%
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)
# sc = Normalizer()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

# %%
# non-uniform = 0.3636, 0.55(2 days)
# uniform = 0.3636
