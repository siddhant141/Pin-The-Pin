# %%
import pandas as pd
import numpy as np
import os
from math import ceil
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.metrics import f1_score
import pickle

# %%
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\400\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    iters=500
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    dfuni=pd.read_csv(path+file)
    last=ceil(dfuni.index[-1]/iters)
    print(dfuni.index[-1])
    print(last)

    fpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Results\\"
#     f = open(fpath+file+"idenhide"+".txt", "w")
#     f.write("\n"+str(dfuni.index[-1]))
#     f.write("\n"+str(last))
    
    fl = open(fpath+file+"loghide"+".txt", "w")
    fl.write("\n"+str(dfuni.index[-1]))
    fl.write("\n"+str(last))

    X = dfuni.iloc[:, 0:n].values
    y = dfuni.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.075)

#     logmodel=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="identity",hidden_layer_sizes=(400,10))
    logmodell=MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic",hidden_layer_sizes=(400,10))

    for i in range(last):

        if(i!=last-1):
            X = X_train[:iters*(i+1)]
            y = y_train[:iters*(i+1)]
        else:
            X=X_train
            y=y_train

        print(X_train.size,X.size)
#         f.write("\n"+str(X_train.size)+str(X.size))
        fl.write("\n"+str(X_train.size)+str(X.size))

#         logmodel.fit(X, y)
        logmodell.fit(X, y)
#         y_pred = logmodel.predict(X_test)
        y_predl = logmodell.predict(X_test)

#         p = logmodel.predict_proba(X_test)
#         nn = 3
#         top_n = np.argsort(p)[:,:-nn-1:-1]
#         #     for i in range(len(y_test)):
#         #         print(y_test[i],top_n[i])
#         count=0
#         count1=0
#         count2=0
#         count3=0
#         count12=0
#         for i in range(len(y_pred)):
#             if(y_test[i] in top_n[i]):
#                 count+=1
#             if(y_test[i] in top_n[i][:2]):
#                 count12+=1
#             if(y_test[i] == top_n[i][0]):
#                 count1+=1
#             elif(y_test[i] == top_n[i][1]):
#                 count2+=1
#             elif(y_test[i] == top_n[i][2]):
#                 count3+=1
#         #         print(y_test[i],y_pred[i])
#         l=len(y_pred)
#         print(file)
#         print(l,count)
#         print("Any one : ",count/l)
#         print("At position 1 and 2 : ",count12/l)
#         print("At position 1 : ",count1/l)
#         print("At position 2 : ",count2/l)
#         print("At position 3 : ",count3/l)
#         print(accuracy_score(y_test, y_pred))

#         f.write("\n"+file)
#         f.write("\n"+str(l)+str(count))
#         f.write("\nAny one : "+str(count/l))
#         f.write("\nAt position 1 and 2 : "+str(count12/l))
#         f.write("\nAt position 1 : "+str(count1/l))
#         f.write("\nAt position 2 : "+str(count2/l))
#         f.write("\nAt position 3 : "+str(count3/l))
#         f.write("\n"+str(accuracy_score(y_test, y_pred)))
        
        p = logmodell.predict_proba(X_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        count=0
        count1=0
        count2=0
        count3=0
        count12=0
        for i in range(len(y_predl)):
            if(y_test[i] in top_n[i]):
                count+=1
            if(y_test[i] in top_n[i][:2]):
                count12+=1
            if(y_test[i] == top_n[i][0]):
                count1+=1
            elif(y_test[i] == top_n[i][1]):
                count2+=1
            elif(y_test[i] == top_n[i][2]):
                count3+=1
        #         print(y_test[i],y_pred[i])
        l=len(y_predl)
        print(file)
        print(l,count)
        print("Any one : ",count/l)
        print("At position 1 and 2 : ",count12/l)
        print("At position 1 : ",count1/l)
        print("At position 2 : ",count2/l)
        print("At position 3 : ",count3/l)
        print(accuracy_score(y_test, y_predl))

        fl.write("\n"+file)
        fl.write("\n"+str(l)+str(count))
        fl.write("\nAny one : "+str(count/l))
        fl.write("\nAt position 1 and 2 : "+str(count12/l))
        fl.write("\nAt position 1 : "+str(count1/l))
        fl.write("\nAt position 2 : "+str(count2/l))
        fl.write("\nAt position 3 : "+str(count3/l))
        fl.write("\n"+str(accuracy_score(y_test, y_predl)))

#     f.close()
    fl.close()
    
# filename = "zmlp500_"+file[:-4]+".sav"
# pickle.dump(logmodel, open(modelpath+filename, 'wb'))
# Out:
# 2724
# 6
# 3024000 600000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 118
# Any one :  0.5756097560975609
# At position 1 and 2 :  0.43414634146341463
# At position 1 :  0.2731707317073171
# At position 2 :  0.16097560975609757
# At position 3 :  0.14146341463414633
# 0.2731707317073171
# 3024000 1200000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 120
# Any one :  0.5853658536585366
# At position 1 and 2 :  0.4634146341463415
# At position 1 :  0.23902439024390243
# At position 2 :  0.22439024390243903
# At position 3 :  0.12195121951219512
# 0.23902439024390243
# 3024000 1800000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 133
# Any one :  0.6487804878048781
# At position 1 and 2 :  0.5121951219512195
# At position 1 :  0.2975609756097561
# At position 2 :  0.2146341463414634
# At position 3 :  0.13658536585365855
# 0.2975609756097561
# 3024000 2400000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 142
# Any one :  0.6926829268292682
# At position 1 and 2 :  0.5463414634146342
# At position 1 :  0.36097560975609755
# At position 2 :  0.18536585365853658
# At position 3 :  0.14634146341463414
# 0.36097560975609755
# 3024000 3000000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 146
# Any one :  0.7121951219512195
# At position 1 and 2 :  0.5756097560975609
# At position 1 :  0.3463414634146341
# At position 2 :  0.22926829268292684
# At position 3 :  0.13658536585365855
# 0.3463414634146341
# 3024000 3024000
# Acc_wGyro_400_window_4b0c17&4b0c18_1200.csv
# 205 148
# Any one :  0.7219512195121951
# At position 1 and 2 :  0.5560975609756098
# At position 1 :  0.3463414634146341
# At position 2 :  0.2097560975609756
# At position 3 :  0.16585365853658537
# 0.3463414634146341
# 2729
# 6
# 3030000 600000
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 205 99
# Any one :  0.48292682926829267
# At position 1 and 2 :  0.33170731707317075
# At position 1 :  0.2097560975609756
# At position 2 :  0.12195121951219512
# At position 3 :  0.15121951219512195
# 0.2097560975609756
# 3030000 1200000
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 205 105
# Any one :  0.5121951219512195
# At position 1 and 2 :  0.37073170731707317
# At position 1 :  0.2048780487804878
# At position 2 :  0.16585365853658537
# At position 3 :  0.14146341463414633
# 0.2048780487804878
# 3030000 1800000
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 205 128
# Any one :  0.624390243902439
# At position 1 and 2 :  0.4585365853658537
# At position 1 :  0.25365853658536586
# At position 2 :  0.2048780487804878
# At position 3 :  0.16585365853658537
# 0.25365853658536586
# 3030000 2400000
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 205 129
# Any one :  0.6292682926829268
# At position 1 and 2 :  0.4975609756097561
# At position 1 :  0.2926829268292683
# At position 2 :  0.2048780487804878
# At position 3 :  0.13170731707317074
# 0.2926829268292683
# 3030000 3000000
# Acc_wGyro_400_wininituniend_4b0c17&4b0c18_1200.csv
# 205