# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier # NN. very much useful and hidden layers. 0.31
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Using\\"
# path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
score=[]
score12=[]
# modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Spike\\Models\\"
modelpath="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Data\\Models\\"

# %%
for file in pathex:
    ni=file.rfind("_")+1
    n=int(file[ni:].split(".")[0])
    df=pd.read_csv(path+file)
    x = df.iloc[:, 0:n].values
    y = df.iloc[:, n].values
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
#     sc = StandardScaler()
#     X_train = sc.fit_transform(X_train)
#     X_test = sc.transform(X_test)
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic",hidden_layer_sizes=(800,10))
#     logmodel = MLPClassifier(solver="lbfgs",max_iter=500,warm_start=True,activation="logistic")
    logmodel = MLPClassifier(solver="lbfgs",max_iter=1500,warm_start=True,activation="logistic")
    logmodel.fit(X_train, y_train)
#     y_pred = logmodel.predict(X_train)
#     print(file,end=" : ")
#     print(accuracy_score(y_train,y_pred))
    y_pred = logmodel.predict(X_test)
    
    p = logmodel.predict_proba(X_test)
    nn = 3
    top_n = np.argsort(p)[:,:-nn-1:-1]
#     for i in range(len(y_test)):
#         print(y_test[i],top_n[i])
    count=0
    count1=0
    count2=0
    count3=0
    count12=0
    for i in range(len(y_pred)):
        if(y_test[i] in top_n[i]):
            count+=1
        if(y_test[i] in top_n[i][:2]):
            count12+=1
        if(y_test[i] == top_n[i][0]):
            count1+=1
        elif(y_test[i] == top_n[i][1]):
            count2+=1
        elif(y_test[i] == top_n[i][2]):
            count3+=1
#         print(y_test[i],y_pred[i])
    l=len(y_pred)
    print(file)
    print(l,count)
    print("Any one : ",count/l)
    print("At position 1 and 2 : ",count12/l)
    print("At position 1 : ",count1/l)
    print("At position 2 : ",count2/l)
    print("At position 3 : ",count3/l)
    score.append([accuracy_score(y_test, y_pred),file,count12/l])
    
print("----------------------------------------------Test : --------------------------------------")
for i in range(len(score)):
#     print(score[i][1]+" : "+str(score[i][0]))
    print(score[i][1])
for i in range(len(score)):
    print(score[i][0])
print("----------------------------------------------2nd guess : --------------------------------------")
for i in range(len(score)):
    print(score[i][2])
# print("------------------------------------------Test : ----------------------------------------")
# for i in range(len(score)):
#     print(score12[i][1]+" : "+str(score12[i][0]))
# df
# Out:
# Acc_wGyro_400_winuni_4b0c17&4b0c18_1200.csv
# 683 624
# Any one :  0.9136163982430454
# At position 1 and 2 :  0.8433382137628112
# At position 1 :  0.5900439238653001
# At position 2 :  0.25329428989751096
# At position 3 :  0.07027818448023426
# Acc_wGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# 683 571
# Any one :  0.83601756954612
# At position 1 and 2 :  0.7349926793557833
# At position 1 :  0.4743777452415813
# At position 2 :  0.26061493411420206
# At position 3 :  0.10102489019033675
# Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.csv
# 678 606
# Any one :  0.8938053097345132
# At position 1 and 2 :  0.7935103244837758
# At position 1 :  0.5471976401179941
# At position 2 :  0.24631268436578171
# At position 3 :  0.10029498525073746
# Acc_wGyro_600_winuniend_4b0c17&4b0c18_1800.csv
# 655 541
# Any one :  0.8259541984732824
# At position 1 and 2 :  0.7007633587786259
# At position 1 :  0.4717557251908397
# At position 2 :  0.22900763358778625
# At position 3 :  0.1251908396946565
# Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.csv
# 637 569
# Any one :  0.8932496075353218
# At position 1 and 2 :  0.8069073783359497
# At position 1 :  0.576138147566719
# At position 2 :  0.23076923076923078
# At position 3 :  0.08634222919937205
# Acc_wGyro_800_winuniend_4b0c17&4b0c18_2400.csv
# 655 536
# Any one :  0.8183206106870229
# At position 1 and 2 :  0.6992366412213741
# At position 1 :  0.46106870229007635
# At position 2 :  0.2381679389312977
# At position 3 :  0.11908396946564885
# Acc_w_200_winuni_4b0c17&4b0c18_600.csv
# 683 571
# Any one :  0.83601756954612
# At position 1 and 2 :  0.6896046852122987
# At position 1 :  0.44216691068814057
# At position 2 :  0.24743777452415813
# At position 3 :  0.14641288433382138
# Acc_w_200_winuniend_4b0c17&4b0c18_600.csv
# 683 493
# Any one :  0.7218155197657394
# At position 1 and 2 :  0.5768667642752562
# At position 1 :  0.3601756954612006
# At position 2 :  0.21669106881405564
# At position 3 :  0.14494875549048317
# Acc_w_400_winuni_4b0c17&4b0c18_1200.csv
# 679 562
# Any one :  0.8276877761413843
# At position 1 and 2 :  0.6833578792341679
# At position 1 :  0.4418262150220913
# At position 2 :  0.24153166421207659
# At position 3 :  0.14432989690721648
# Acc_w_400_winuniend_4b0c17&4b0c18_1200.csv
# 655 494
# Any one :  0.7541984732824427
# At position 1 and 2 :  0.6183206106870229
# At position 1 :  0.39236641221374047
# At position 2 :  0.22595419847328244
# At position 3 :  0.13587786259541984
# ----------------------------------------------Test : --------------------------------------
# Acc_wGyro_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_wGyro_400_winuniend_4b0c17&4b0c18_1200.csv
# Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.csv
# Acc_wGyro_600_winuniend_4b0c17&4b0c18_1800.csv
# Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.csv
# Acc_wGyro_800_winuniend_4b0c17&4b0c18_2400.csv
# Acc_w_200_winuni_4b0c17&4b0c18_600.csv
# Acc_w_200_winuniend_4b0c17&4b0c18_600.csv
# Acc_w_400_winuni_4b0c17&4b0c18_1200.csv
# Acc_w_400_winuniend_4b0c17&4b0c18_1200.csv
# 0.5900439238653001
# 0.4743777452415813
# 0.5471976401179941
# 0.4717557251908397
# 0.576138147566719
# 0.46106870229007635
# 0.44216691068814057
# 0.3601756954612006
# 0.4418262150220913
# 0.39236641221374047
# ----------------------------------------------2nd guess : --------------------------------------
# 0.8433382137628112
# 0.7349926793557833
# 0.7935103244837758
# 0.7007633587786259
# 0.8069073783359497
# 0.6992366412213741
# 0.6896046852122987
# 0.5768667642752562
# 0.6833578792341679
# 0.6183206106870229
