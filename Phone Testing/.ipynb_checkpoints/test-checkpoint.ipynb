# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
pathm="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Phone\\Using model\\"
pathmex = [f for f in listdir(pathm) if isfile(join(pathm, f))]
pathmex.sort()
# pathex=["Gyro_400_window_a29c08&66b325&b56522_1200.csv"]
# filem=pathmex[0]

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Phone\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
# file=pathex[0]
for filem in pathmex:
    for file in pathex:
        ni=file.rfind("_")+1
        n=int(file[ni:].split(".")[0])
        nim=filem.rfind("_")+1
        nm=int(filem[nim:].split(".")[0])
        if(n!=nm):
            continue
        df=pd.read_csv(path+file)
        x_test = df.iloc[:, 0:n].values
        y_test = df.iloc[:, n].values
        logmodel=pickle.load(open(pathm+filem, 'rb'))
        y_pred = logmodel.predict(x_test)

        # print(y_pred,y)

        p = logmodel.predict_proba(x_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        print(filem)
        print(file)
        print(y_test)
        print(y_pred)
        print(top_n)
        print()
#         count=0
#         count12=0
#         for i in range(len(y_pred)):
#             if(y_test[i] in top_n[i]):
#                 count+=1
#             if(y_test[i] in top_n[i][:2]):
#                 count12+=1
#     #         print(y_test[i],top_n[i])
#         l=len(y_pred)
#         print(filem)
#         print(file)
#         print("f1score : ",f1_score(y_test, y_pred, average="micro"))
#         print("accuracy score : ", accuracy_score(y_test,y_pred))
#         print(count/l)
#         print("At position 1 or 2 : ",count12/l)
#         print(classification_report(y_test, y_pred))
# Out:
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [9 0 5 4]
# [[9 8 0]
#  [0 8 7]
#  [5 7 8]
#  [4 1 2]]
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [9 9 3 4]
# [[9 8 5]
#  [9 5 3]
#  [3 9 5]
#  [4 1 7]]
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [7 9 7 0]
# [[7 0 4]
#  [9 0 6]
#  [7 9 1]
#  [0 8 7]]
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [8 7 1 7]
# [[8 0 7]
#  [7 8 0]
#  [1 5 9]
#  [7 1 4]]
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [4 0 5 4]
# [[4 0 7]
#  [0 8 9]
#  [5 7 0]
#  [4 1 2]]
# logistic500_Acc_wGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [4 7 5 4]
# [[4 3 9]
#  [7 0 4]
#  [5 6 9]
#  [4 1 7]]
# logistic500_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [3 3 3 3]
# [[3 6 9]
#  [3 9 6]
#  [3 2 5]
#  [3 2 7]]
# logistic500_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [3 3 3 3]
# [[3 6 9]
#  [3 6 9]
#  [3 6 9]
#  [3 7 2]]
# logistic500_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [6 9 3 4]
# [[6 2 1]
#  [9 0 8]
#  [3 6 2]
#  [4 1 7]]
# logistic500_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [9 4 3 4]
# [[9 6 4]
#  [4 6 5]
#  [3 6 5]
#  [4 7 1]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 2 3]
#  [1 2 5]
#  [1 2 3]
#  [1 2 3]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 3 2]
#  [1 3 2]
#  [1 3 2]
#  [1 2 3]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [7 9 6 6]
# [[7 6 8]
#  [9 6 0]
#  [6 9 8]
#  [6 8 3]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [7 7 8 8]
# [[7 4 8]
#  [7 8 5]
#  [8 7 9]
#  [8 6 4]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [5 0 7 4]
# [[5 4 2]
#  [0 9 8]
#  [7 5 8]
#  [4 7 1]]
# logistic500_Acc_woGyro_600_winuni_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [5 5 5 4]
# [[5 3 4]
#  [5 4 7]
#  [5 0 8]
#  [4 7 1]]
# logistic_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [6 6 3 6]
# [[6 3 2]
#  [6 3 2]
#  [3 6 2]
#  [6 3 2]]
# logistic_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [6 6 6 6]
# [[6 3 9]
#  [6 3 9]
#  [6 3 9]
#  [6 3 2]]
# logistic_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [6 8 3 4]
# [[6 2 4]
#  [8 9 6]
#  [3 6 2]
#  [4 7 1]]
# logistic_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [6 4 3 4]
# [[6 4 5]
#  [4 2 6]
#  [3 6 5]
#  [4 1 7]]
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [0 9 2 4]
# [[0 8 9]
#  [9 0 8]
#  [2 5 6]
#  [4 7 1]]
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [9 9 9 4]
# [[9 6 8]
#  [9 0 8]
#  [9 6 3]
#  [4 1 7]]
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [3 9 3 1]
# [[3 6 9]
#  [9 6 8]
#  [3 6 2]
#  [1 4 7]]
# mlp500_iden_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [3 9 3 1]
# [[3 6 2]
#  [9 8 6]
#  [3 6 2]
#  [1 4 2]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [3 0 2 4]
# [[3 6 2]
#  [0 9 8]
#  [2 5 3]
#  [4 7 1]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [8 8 9 4]
# [[8 6 9]
#  [8 5 7]
#  [9 7 5]
#  [4 7 1]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [8 0 5 9]
# [[8 0 5]
#  [0 9 6]
#  [5 9 7]
#  [9 8 5]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [8 5 3 8]
# [[8 5 6]
#  [5 2 3]
#  [3 8 5]
#  [8 4 9]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [9 0 9 9]
# [[9 8 6]
#  [0 8 9]
#  [9 6 8]
#  [9 8 0]]
# mlp500_iden_Acc_wGyro_800_window_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [9 4 3 8]
# [[9 6 4]
#  [4 9 6]
#  [3 6 2]
#  [8 9 1]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [0 9 9 8]
# [[0 7 8]
#  [9 0 6]
#  [9 8 6]
#  [8 0 4]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [9 6 8 8]
# [[9 8 6]
#  [6 9 3]
#  [8 0 6]
#  [8 0 7]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [8 9 0 4]
# [[8 0 5]
#  [9 0 8]
#  [0 8 5]
#  [4 7 1]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [9 8 9 4]
# [[9 8 0]
#  [8 5 0]
#  [9 8 6]
#  [4 1 7]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [0 9 0 7]
# [[0 7 4]
#  [9 8 0]
#  [0 5 7]
#  [7 4 1]]
# mlp500_idenhide_Acc_wGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [5 7 5 4]
# [[5 2 1]
#  [7 4 0]
#  [5 9 8]
#  [4 1 7]]
# mlp500_idenhide_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [3 3 3 3]
# [[3 9 8]
#  [3 9 8]
#  [3 9 8]
#  [3 9 8]]
# mlp500_idenhide_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [3 3 3 3]
# [[3 9 8]
#  [3 9 8]
#  [3 9 8]
#  [3 9 8]]
# mlp500_idenhide_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [6 0 2 4]
# [[6 4 2]
#  [0 9 8]
#  [2 3 5]
#  [4 7 1]]
# mlp500_idenhide_Acc_woGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [7 4 3 4]
# [[7 9 4]
#  [4 1 2]
#  [3 5 2]
#  [4 1 7]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [2 2 2 2]
# [[2 3 9]
#  [2 3 9]
#  [2 3 9]
#  [2 3 9]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_wGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [2 2 2 2]
# [[2 3 9]
#  [2 3 9]
#  [2 3 9]
#  [2 3 9]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [9 9 2 7]
# [[9 6 8]
#  [9 8 0]
#  [2 6 3]
#  [7 4 1]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_window_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [5 5 2 4]
# [[5 9 6]
#  [5 2 4]
#  [2 5 4]
#  [4 7 1]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_01_14_09_PM_1800.csv
# [0 1 2 3]
# [4 9 9 9]
# [[4 5 8]
#  [9 8 0]
#  [9 0 8]
#  [9 8 6]]
# mlp500_idenhide_Acc_woGyro_600_window_4b0c17&4b0c18_1800.sav
# Acc_woGyro_600_winuni_4b0c22_12_49_58_PM_1800.csv
# [0 1 2 3]
# [9 9 9 9]
# [[9 6 3]
#  [9 5 4]
#  [9 6 0]
#  [9 6 8]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 9 8]
#  [1 9 8]
#  [1 9 8]
#  [1 9 8]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_window_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 9 8]
#  [1 9 8]
#  [1 9 8]
#  [1 9 8]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 9 8]
#  [1 9 8]
#  [1 9 8]
#  [1 9 8]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_wGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [1 1 1 1]
# [[1 9 8]
#  [1 9 8]
#  [1 9 8]
#  [1 9 8]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_01_14_09_PM_2400.csv
# [0 1 2 3]
# [4 9 4 7]
# [[4 7 5]
#  [9 8 6]
#  [4 7 1]
#  [7 4 0]]
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c22_12_49_58_PM_2400.csv
# [0 1 2 3]
# [7 4 0 7]
# [[7 5 6]
#  [4 1 7]
#  [0 5 7]
#  [7 4 1]]
# mlp_1500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [0 0 5 4]
# [[0 8 9]
#  [0 9 8]
#  [5 6 3]
#  [4 7 1]]
# mlp_1500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_wGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [9 9 9 4]
# [[9 8 6]
#  [9 0 8]
#  [9 6 8]
#  [4 7 1]]
# mlp_1500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_01_14_09_PM_1200.csv
# [0 1 2 3]
# [3 0 3 1]
# [[3 6 2]
#  [0 9 8]
#  [3 6 2]
#  [1 4 7]]
# mlp_1500_Acc_wGyro_400_window_4b0c17&4b0c18_1200.sav
# Acc_woGyro_400_window_4b0c22_12_49_58_PM_1200.csv
# [0 1 2 3]
# [3 3 3 1]
# [[3 6 2]
#  [3 6 4]
#  [3 2 6]
#  [1 4 7]]
