# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import metrics
from os import listdir
from os.path import isfile, join
from sklearn.preprocessing import Normalizer
from sklearn.metrics import f1_score
import pickle

# %%
pathm="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Phone\\Using model\\"
pathmex = [f for f in listdir(pathm) if isfile(join(pathm, f))]
pathmex.sort()
# pathex=["Gyro_400_window_a29c08&66b325&b56522_1200.csv"]
# filem=pathmex[0]

# %%
path="C:\\Users\\nilu1\\Desktop\\Code\\AndroidPattern\\Phone\\Using\\"
pathex = [f for f in listdir(path) if isfile(join(path, f))]
pathex.sort()
# file=pathex[0]
for filem in pathmex:
    for file in pathex:
        ni=file.rfind("_")+1
        n=int(file[ni:].split(".")[0])
        nim=filem.rfind("_")+1
        nm=int(filem[nim:].split(".")[0])
        if(n!=nm):
            continue
        df=pd.read_csv(path+file)
        x_test = df.iloc[:, 0:n].values
        y_test = df.iloc[:, n].values
        logmodel=pickle.load(open(pathm+filem, 'rb'))
        y_pred = logmodel.predict(x_test)

        # print(y_pred,y)

        p = logmodel.predict_proba(x_test)
        nn = 3
        top_n = np.argsort(p)[:,:-nn-1:-1]
        print(filem)
        print(file)
        print(y_test)
        print(y_pred)
        print(top_n)
        print()
#         count=0
#         count12=0
#         for i in range(len(y_pred)):
#             if(y_test[i] in top_n[i]):
#                 count+=1
#             if(y_test[i] in top_n[i][:2]):
#                 count12+=1
#     #         print(y_test[i],top_n[i])
#         l=len(y_pred)
#         print(filem)
#         print(file)
#         print("f1score : ",f1_score(y_test, y_pred, average="micro"))
#         print("accuracy score : ", accuracy_score(y_test,y_pred))
#         print(count/l)
#         print("At position 1 or 2 : ",count12/l)
#         print(classification_report(y_test, y_pred))
# Out:
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_19_21_PM_2400.csv
# [0 1 2 3]
# [7 5 7 5]
# [[7 4 0]
#  [5 3 7]
#  [7 8 0]
#  [5 8 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_20_11_PM_2400.csv
# [0 1 2 3]
# [7 7 7 8]
# [[7 4 2]
#  [7 4 0]
#  [7 0 8]
#  [8 0 5]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_21_26_PM_2400.csv
# [0 1 2 3]
# [7 0 4 7]
# [[7 5 8]
#  [0 7 8]
#  [4 7 5]
#  [7 4 2]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_22_33_PM_2400.csv
# [0 1 2 3]
# [4 7 7 7]
# [[4 2 1]
#  [7 1 4]
#  [7 4 8]
#  [7 0 6]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_23_10_PM_2400.csv
# [0 1 2 3]
# [7 4 7 7]
# [[7 0 5]
#  [4 7 1]
#  [7 0 5]
#  [7 5 2]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_24_54_PM_2400.csv
# [0 1 2 3]
# [4 7 7 7]
# [[4 7 1]
#  [7 4 0]
#  [7 4 8]
#  [7 2 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_25_29_PM_2400.csv
# [0 1 2 3]
# [7 4 8 1]
# [[7 0 4]
#  [4 7 8]
#  [8 5 0]
#  [1 4 7]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_26_10_PM_2400.csv
# [0 1 2 3]
# [9 7 7 3]
# [[9 5 4]
#  [7 4 1]
#  [7 0 4]
#  [3 5 8]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_27_37_PM_2400.csv
# [0 1 2 3]
# [2 0 7 7]
# [[2 3 4]
#  [0 7 4]
#  [7 8 0]
#  [7 1 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_28_09_PM_2400.csv
# [0 1 2 3]
# [4 7 0 2]
# [[4 7 1]
#  [7 4 5]
#  [0 6 5]
#  [2 7 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_28_36_PM_2400.csv
# [0 1 2 3]
# [4 2 4 7]
# [[4 7 2]
#  [2 5 4]
#  [4 7 1]
#  [7 0 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_29_16_PM_2400.csv
# [0 1 2 3]
# [4 1 4 2]
# [[4 3 5]
#  [1 4 7]
#  [4 7 1]
#  [2 4 3]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_29_51_PM_2400.csv
# [0 1 2 3]
# [0 7 4 8]
# [[0 7 3]
#  [7 4 5]
#  [4 7 1]
#  [8 0 5]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_30_25_PM_2400.csv
# [0 1 2 3]
# [4 4 7 2]
# [[4 7 5]
#  [4 7 5]
#  [7 4 0]
#  [2 0 7]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_39_27_PM_2400.csv
# [0 1 2 3]
# [5 6 4 0]
# [[5 7 0]
#  [6 8 4]
#  [4 7 5]
#  [0 8 7]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_40_17_PM_2400.csv
# [0 1 2 3]
# [4 5 7 1]
# [[4 7 2]
#  [5 4 9]
#  [7 1 4]
#  [1 4 7]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_40_52_PM_2400.csv
# [0 1 2 3]
# [4 8 1 8]
# [[4 5 7]
#  [8 5 4]
#  [1 4 7]
#  [8 6 5]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_41_37_PM_2400.csv
# [0 1 2 3]
# [4 4 4 7]
# [[4 7 1]
#  [4 7 8]
#  [4 7 2]
#  [7 4 1]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_42_08_PM_2400.csv
# [0 1 2 3]
# [4 9 7 1]
# [[4 5 7]
#  [9 8 6]
#  [7 5 0]
#  [1 7 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_42_42_PM_2400.csv
# [0 1 2 3]
# [4 7 7 7]
# [[4 7 1]
#  [7 0 4]
#  [7 0 8]
#  [7 0 9]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_43_14_PM_2400.csv
# [0 1 2 3]
# [4 4 7 7]
# [[4 7 1]
#  [4 7 5]
#  [7 4 1]
#  [7 4 5]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_43_55_PM_2400.csv
# [0 1 2 3]
# [9 8 7 7]
# [[9 8 0]
#  [8 0 7]
#  [7 4 2]
#  [7 5 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_44_27_PM_2400.csv
# [0 1 2 3]
# [0 0 7 2]
# [[0 9 5]
#  [0 5 7]
#  [7 4 0]
#  [2 3 4]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_44_54_PM_2400.csv
# [0 1 2 3]
# [5 7 7 4]
# [[5 8 7]
#  [7 4 8]
#  [7 0 5]
#  [4 5 7]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_46_01_PM_2400.csv
# [0 1 2 3]
# [7 4 9 6]
# [[7 0 8]
#  [4 7 1]
#  [9 0 5]
#  [6 3 5]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_46_37_PM_2400.csv
# [0 1 2 3]
# [6 4 4 8]
# [[6 5 8]
#  [4 1 7]
#  [4 7 5]
#  [8 5 0]]
#
# mlp500_idenhide_Acc_woGyro_800_winuni_4b0c17&4b0c18_2400.sav
# Acc_woGyro_800_winuni_4b0c23_02_47_15_PM_2400.csv
# [0 1 2 3]
# [4 4 7 4]
# [[4 1 2]
#  [4 7 5]
#  [7 4 8]
#  [4 2 3]]
